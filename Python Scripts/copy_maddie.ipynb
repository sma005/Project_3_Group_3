# %%
# Import Depencies

import matplotlib.pyplot as plt
import pandas as pd
import polars as pl
import numpy as np
import requests
from pprint import pprint
import time
import json
from requests.structures import CaseInsensitiveDict

from apikey import apikey

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Section for user input. 
# Create empty variables to let the user input coordinates. Create city/coordinate options for users who do not want to input their own coordinates.
lat = ''
lon = ''

default = [0, 0]
cleveland = [41.4993, -81.6944]
atlanta = [33.7488, -84.3877]
los_angeles = [34.0549, -118.2426]
new_york_city = [40.7128, -74.0060]
chicago = [41.8781, -87.6298]
seattle = [47.6061, -122.3328]

# Set up variable for user to search for their own coordinates. User_defined or written to pre-determined
location_search = [123456789,123456789] 

# Create list of cities with pre-written coordinates
default_city_list =  {'Cleveland' : cleveland , 'Atlanta' : atlanta, 'Los Angeles' : los_angeles, 'New York City' : new_york_city, 'Chicago' : chicago, 'Seattle' : seattle}

# Display cities for user to consider pre-written options
print('Available list of cities\n')
for k, v in default_city_list.items():
    print(k)
# Out:
# Available list of cities
#
# Cleveland
# Atlanta
# Los Angeles
# New York City
# Chicago
# Seattle

# %%
# Ask user for input on if they would like to pick from pre-written cities
user_coordinates = input("Would you like pick from a list of available cities? yes or no")

# If they choose to use a pre-written city, have the user pick a city from the pre-written list
if user_coordinates.lower() == 'y' or user_coordinates.lower() == 'yes':

    match = input("Please pick a city from the list.\n")

    for k, v in default_city_list.items():
        if match.lower() == k.lower():
            location_search = v

# If the user does not want to pick from the pre-written list, allow them to input their own coordinates
elif user_coordinates.lower() == 'n' or user_coordinates.lower() == 'no':
    user_lat = input("Please enter the latitude. ")
    user_lon = input("Please enter the longitude. ")
    location_search = [float(user_lat), float(user_lon)]

# Let the user know that their only options are to pick from the list or not pick from the list
else:
    raise Exception("Invalid Input. Must specify Yes (y) or No (n)")

# Make sure the location search is filled in with city coordinates every time
if location_search == [123456789, 123456789]:
    raise Exception("Invalid location. Use a name that is in the list, or choose No (n) your own coordinates.")

# Display the coordinates that will be used in the location search    
print(f'Using coordinates {location_search}\n')
# Out:
# Using coordinates [47.6061, -122.3328]

# %%
# Set search parameters as default values, except for the country code which will be filled in later
radius_meters = 5000
country_code = ''
limit = 120
offset = 0 #default is zero


# Set the filter to search for locations within the parameters
location_filter = f'circle:{location_search[1]},{location_search[0]},{radius_meters}'

# Keep for future flexibility
if country_code != "":
    country_code = country_code + f"|countrycode:{country_code}"

# Format headers to be used later
headers = CaseInsensitiveDict()
headers["Accept"] = "application/json"

# %%
# Create categories to be filled in to filter data in search. Any category can be added - it must also be added to category_dict in the next cell
category_string = ""

activity = True
commercial = True
commercial_catering = False
commercial_supermarket = True
accomodations = False
entertainment = True
leisure = False
parking = False
wheelchair = False

# %%
# Create dictionary to house each category that will be captured
# we also may want to include user input for this too. Loop through these, or other questions. Set value to True. Default value is false. Must have at least one of these active in order
# to run the script. If not, throw an error
# We either need to specify that the list needs to be under 500, because that is the max number, or create 
category_dict = {'activity' : activity, 'commercial' : commercial, 'commerical.catering' : commercial_catering, 'accomodation' : accomodations, \
                        'entertainment' : entertainment, 'leisure': leisure, 'parking' : parking, 'wheelchair.yes' : wheelchair}

# Set up string to input categories to add to base url
string_of_categories = ""

# Capture the key for each category we want to include in the search
for k,v in category_dict.items():
    if v:
        string_of_categories = string_of_categories + k + ','

# Remove last comma
string_of_categories = string_of_categories[:-1]

# API string built for flexibility
url2 = f"https://api.geoapify.com/v2/places?categories={string_of_categories}&filter={location_filter}&limit={limit}&offset={offset}&apiKey={apikey}"

# %%
# Search API / get API dictionary
resp = requests.get(url2, headers=headers)

# View response status to see if search was successful
print(resp.status_code)

# Store the response to manipulate data received
json_info = resp.json()

# Check to see if search was successful, comment this out once data has been checked
#pprint(json_info)
# Out:
# 200

# %%
# View first response, only for debugging, may be commented out later
json_info["features"][0]
# Out:
# {'type': 'Feature',
#  'properties': {'name': 'Seattle Aquarium',
#   'country': 'United States',
#   'country_code': 'us',
#   'state': 'Washington',
#   'county': 'King County',
#   'city': 'Seattle',
#   'postcode': '98101',
#   'district': 'West Edge',
#   'suburb': 'Belltown',
#   'street': 'Alaskan Way',
#   'housenumber': '1483',
#   'lon': -122.34322017076866,
#   'lat': 47.60762475,
#   'state_code': 'WA',
#   'formatted': 'Seattle Aquarium, 1483 Alaskan Way, Seattle, WA 98101, United States of America',
#   'address_line1': 'Seattle Aquarium',
#   'address_line2': '1483 Alaskan Way, Seattle, WA 98101, United States of America',
#   'categories': ['building',
#    'building.tourism',
#    'entertainment',
#    'entertainment.aquarium',
#    'fee',
#    'wheelchair',
#    'wheelchair.yes'],
#   'details': ['details',
#    'details.building',
#    'details.contact',
#    'details.facilities',
#    'details.wiki_and_media'],
#   'datasource': {'sourcename': 'openstreetmap',
#    'attribution': '© OpenStreetMap contributors',
#    'license': 'Open Database Licence',
#    'url': 'https://www.openstreetmap.org/copyright',
#    'raw': {'ele': 5,
#     'fax': '+1 206 682 7240',
#     'fee': 'yes',
#     'name': 'Seattle Aquarium',
#     'email': 'contactus@seattleaquarium.org',
#     'phone': '+1-206-386-4300',
#     'osm_id': 16051213,
#     'name:ko': '시애틀 수족관',
#     'smoking': 'no',
#     'tourism': 'aquarium',
#     'website': 'https://www.seattleaquarium.org/',
#     'building': 'yes',
#     'operator': 'Seattle Museum Society',
#     'osm_type': 'r',
#     'wikidata': 'Q4849544',
#     'addr:city': 'Seattle',
#     'wikipedia': 'en:Seattle Aquarium',
#     'addr:state': 'WA',
#     'start_date': 1977,
#     'wheelchair': 'yes',
#     'addr:street': 'Alaskan Way',
#     'contact:fax': '+1-206-3864328',
#     'addr:postcode': 98101,
#     'opening_hours': 'Mo-Su 09:00-18:00',
#     'operator:type': 'nonprofit',
#     'addr:housenumber': 1483,
#     'safety:mask:covid19': 'yes'}},
#   'place_id': '51968bbfbaf5955ec059789e04d9c4cd4740f00101f9010decf4000000000092031053656174746c6520417175617269756d'},
#  'geometry': {'type': 'Point',
#   'coordinates': [-122.34312313752739, 47.60756981587923]}}

# %%
# Create error checking to make sure it is only US locations. String split is based on US cities.
# Do this to prevent the code from stalling with cities in other countries which have differently formatted data
if json_info["features"][0]["properties"]["country_code"] != 'us':
    raise Exception('This process is built for US cities only.')

# %%
# Create dataframe from the stored json response from the API search
features_pd = pd.json_normalize(json_info["features"])

# %%
# Create dataframe which will become the first table in the future database. Only take categories which hold address and location information as columns for new df
properties_df = features_pd[["properties.address_line1", "properties.address_line2", "properties.place_id"]]

# %%
# Rename columns
properties_df = properties_df.rename(columns = {"properties.address_line1": "Property", "properties.address_line2": "Address2", "properties.place_id": "Place_ID"})

# View dataframe to see if this was successful, may be commented out once confirmed
#properties_df

# %%
# View top of new dataframe to see what we are working with and decide next steps
properties_df.head(5)
# Out:
#                      Property  \
# 0            Seattle Aquarium
# 1             Frye Art Museum
# 2    Seattle Asian Art Museum
# 3     Center for Wooden Boats
# 4  Seattle Children's Theater
#
#                                             Address2  \
# 0  1483 Alaskan Way, Seattle, WA 98101, United St...
# 1  704 Terry Avenue, Seattle, WA 98104, United St...
# 2  1400 East Prospect Street, Seattle, WA 98112, ...
# 3  1010 Valley Street, Seattle, WA 98109, United ...
# 4  201 Thomas Street, Seattle, WA 98109, United S...
#
#                                             Place_ID
# 0  51968bbfbaf5955ec059789e04d9c4cd4740f00101f901...
# 1  51af680970be945ec059ab288eb3b8cd4740f00101f901...
# 2  51cfccbfe11b945ec059fef6e697add04740f00102f901...
# 3  51a34420657f955ec059010bfcf647d04740f00102f901...
# 4  5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901...

# %%
# Create new separate columns for the address fields from the renamed address column
properties_df[['Address', 'City', 'State_Zip', 'Country']] = properties_df.Address2.str.split(",", expand = True)

# %%
# View top of dataframe to confirm process was successful
properties_df.head(5)
# Out:
#                      Property  \
# 0            Seattle Aquarium
# 1             Frye Art Museum
# 2    Seattle Asian Art Museum
# 3     Center for Wooden Boats
# 4  Seattle Children's Theater
#
#                                             Address2  \
# 0  1483 Alaskan Way, Seattle, WA 98101, United St...
# 1  704 Terry Avenue, Seattle, WA 98104, United St...
# 2  1400 East Prospect Street, Seattle, WA 98112, ...
# 3  1010 Valley Street, Seattle, WA 98109, United ...
# 4  201 Thomas Street, Seattle, WA 98109, United S...
#
#                                             Place_ID  \
# 0  51968bbfbaf5955ec059789e04d9c4cd4740f00101f901...
# 1  51af680970be945ec059ab288eb3b8cd4740f00101f901...
# 2  51cfccbfe11b945ec059fef6e697add04740f00102f901...
# 3  51a34420657f955ec059010bfcf647d04740f00102f901...
# 4  5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901...
#
#                      Address      City  State_Zip                    Country
# 0           1483 Alaskan Way   Seattle   WA 98101   United States of America
# 1           704 Terry Avenue   Seattle   WA 98104   United States of America
# 2  1400 East Prospect Street   Seattle   WA 98112   United States of America
# 3         1010 Valley Street   Seattle   WA 98109   United States of America
# 4          201 Thomas Street   Seattle   WA 98109   United States of America

# %%
# Drop any rows with empty values
properties_df = properties_df.dropna()

# %%
# Remove any spaces or whitespaces from data to more easily manipulate
properties_df["State_Zip"] = properties_df['State_Zip'].str.strip()

# %%
# View top of dataframe to confirm process was successful
properties_df.head(5)
# Out:
#                      Property  \
# 0            Seattle Aquarium
# 1             Frye Art Museum
# 2    Seattle Asian Art Museum
# 3     Center for Wooden Boats
# 4  Seattle Children's Theater
#
#                                             Address2  \
# 0  1483 Alaskan Way, Seattle, WA 98101, United St...
# 1  704 Terry Avenue, Seattle, WA 98104, United St...
# 2  1400 East Prospect Street, Seattle, WA 98112, ...
# 3  1010 Valley Street, Seattle, WA 98109, United ...
# 4  201 Thomas Street, Seattle, WA 98109, United S...
#
#                                             Place_ID  \
# 0  51968bbfbaf5955ec059789e04d9c4cd4740f00101f901...
# 1  51af680970be945ec059ab288eb3b8cd4740f00101f901...
# 2  51cfccbfe11b945ec059fef6e697add04740f00102f901...
# 3  51a34420657f955ec059010bfcf647d04740f00102f901...
# 4  5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901...
#
#                      Address      City State_Zip                    Country
# 0           1483 Alaskan Way   Seattle  WA 98101   United States of America
# 1           704 Terry Avenue   Seattle  WA 98104   United States of America
# 2  1400 East Prospect Street   Seattle  WA 98112   United States of America
# 3         1010 Valley Street   Seattle  WA 98109   United States of America
# 4          201 Thomas Street   Seattle  WA 98109   United States of America

# %%
#I don't think we need this anymore
properties_df.State_Zip.str.split(" ", expand = True)
# Out:
#      0      1
# 0   OH  44114
# 1   OH  44114
# 2   OH  44109
# 3   OH  44113
# 4   OH  44115
# ..  ..    ...
# 94  OH  44105
# 95  OH  44105
# 96  OH  44103
# 97  OH  44114
# 98  OH  44105
#
# [98 rows x 2 columns]

# %%
# Split State_Zip column into separate columns for the state and the zip code
properties_df[['State', 'Zip']] = properties_df.State_Zip.str.split(" ", expand = True)

# %%
# View top of dataframe to confirm process was successful
properties_df.head(5)
# Out:
#                      Property  \
# 0            Seattle Aquarium
# 1             Frye Art Museum
# 2    Seattle Asian Art Museum
# 3     Center for Wooden Boats
# 4  Seattle Children's Theater
#
#                                             Address2  \
# 0  1483 Alaskan Way, Seattle, WA 98101, United St...
# 1  704 Terry Avenue, Seattle, WA 98104, United St...
# 2  1400 East Prospect Street, Seattle, WA 98112, ...
# 3  1010 Valley Street, Seattle, WA 98109, United ...
# 4  201 Thomas Street, Seattle, WA 98109, United S...
#
#                                             Place_ID  \
# 0  51968bbfbaf5955ec059789e04d9c4cd4740f00101f901...
# 1  51af680970be945ec059ab288eb3b8cd4740f00101f901...
# 2  51cfccbfe11b945ec059fef6e697add04740f00102f901...
# 3  51a34420657f955ec059010bfcf647d04740f00102f901...
# 4  5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901...
#
#                      Address      City State_Zip                    Country  \
# 0           1483 Alaskan Way   Seattle  WA 98101   United States of America
# 1           704 Terry Avenue   Seattle  WA 98104   United States of America
# 2  1400 East Prospect Street   Seattle  WA 98112   United States of America
# 3         1010 Valley Street   Seattle  WA 98109   United States of America
# 4          201 Thomas Street   Seattle  WA 98109   United States of America
#
#   State    Zip
# 0    WA  98101
# 1    WA  98104
# 2    WA  98112
# 3    WA  98109
# 4    WA  98109

# %%
# Remove the address2 column now that the addresses have been separated into new columns
properties_df = properties_df.drop('Address2', axis=1)

# %%
# Remove the State_Zip column now that the state and zip code have been separated into new columns
properties_df = properties_df.drop('State_Zip', axis=1)

# %%
# View top of dataframe to confirm process was successful
properties_df.head(5)
# Out:
#                      Property  \
# 0            Seattle Aquarium
# 1             Frye Art Museum
# 2    Seattle Asian Art Museum
# 3     Center for Wooden Boats
# 4  Seattle Children's Theater
#
#                                             Place_ID  \
# 0  51968bbfbaf5955ec059789e04d9c4cd4740f00101f901...
# 1  51af680970be945ec059ab288eb3b8cd4740f00101f901...
# 2  51cfccbfe11b945ec059fef6e697add04740f00102f901...
# 3  51a34420657f955ec059010bfcf647d04740f00102f901...
# 4  5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901...
#
#                      Address      City                    Country State    Zip
# 0           1483 Alaskan Way   Seattle   United States of America    WA  98101
# 1           704 Terry Avenue   Seattle   United States of America    WA  98104
# 2  1400 East Prospect Street   Seattle   United States of America    WA  98112
# 3         1010 Valley Street   Seattle   United States of America    WA  98109
# 4          201 Thomas Street   Seattle   United States of America    WA  98109

# %%
# Order the columns in the way in which we will put the data into the database
properties_df = properties_df.reindex(['Place_ID', 'Property', 'Address', 'City', 'State', 'Zip', 'Country'], axis=1)

# %%
# View top of dataframe to confirm process was successful
properties_df
# Out:
#                                               Place_ID  \
# 0    51968bbfbaf5955ec059789e04d9c4cd4740f00101f901...
# 1    51af680970be945ec059ab288eb3b8cd4740f00101f901...
# 2    51cfccbfe11b945ec059fef6e697add04740f00102f901...
# 3    51a34420657f955ec059010bfcf647d04740f00102f901...
# 4    5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901...
# ..                                                 ...
# 115  51fedf7dfa74955ec05970834694f6cd4740f00103f901...
# 116  5170788bd184955ec059b3fbf42801ce4740f00103f901...
# 117  51c7c1114999955ec059fd9237ff0ace4740f00103f901...
# 118  51becf02feba955ec059ad09c31a1dce4740f00103f901...
# 119  5163d68ba19c955ec05972c4160be8cd4740f00103f901...
#
#                        Property                    Address      City State  \
# 0              Seattle Aquarium           1483 Alaskan Way   Seattle    WA
# 1               Frye Art Museum           704 Terry Avenue   Seattle    WA
# 2      Seattle Asian Art Museum  1400 East Prospect Street   Seattle    WA
# 3       Center for Wooden Boats         1010 Valley Street   Seattle    WA
# 4    Seattle Children's Theater          201 Thomas Street   Seattle    WA
# ..                          ...                        ...       ...   ...
# 115       PCC Community Markets            1320 4th Avenue   Seattle    WA
# 116              Joseph Jewelry            1413 4th Avenue   Seattle    WA
# 117                        Ross            301 Pike Street   Seattle    WA
# 118                 Simple Life            201 Pine Street   Seattle    WA
# 119             The Triple Door           216 Union Street   Seattle    WA
#
#        Zip                    Country
# 0    98101   United States of America
# 1    98104   United States of America
# 2    98112   United States of America
# 3    98109   United States of America
# 4    98109   United States of America
# ..     ...                        ...
# 115  98101   United States of America
# 116  98101   United States of America
# 117  98101   United States of America
# 118  98101   United States of America
# 119  98101   United States of America
#
# [118 rows x 7 columns]

# %%
#There is something wrong with this. I don't know what
# properties_df = properties_df.drop_duplicates(subset = "Place_ID", inplace = True)

# %%
# View top of dataframe to confirm process was successful
properties_df.head(5)
# Out:
#                                             Place_ID  \
# 0  51968bbfbaf5955ec059789e04d9c4cd4740f00101f901...
# 1  51af680970be945ec059ab288eb3b8cd4740f00101f901...
# 2  51cfccbfe11b945ec059fef6e697add04740f00102f901...
# 3  51a34420657f955ec059010bfcf647d04740f00102f901...
# 4  5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901...
#
#                      Property                    Address      City State  \
# 0            Seattle Aquarium           1483 Alaskan Way   Seattle    WA
# 1             Frye Art Museum           704 Terry Avenue   Seattle    WA
# 2    Seattle Asian Art Museum  1400 East Prospect Street   Seattle    WA
# 3     Center for Wooden Boats         1010 Valley Street   Seattle    WA
# 4  Seattle Children's Theater          201 Thomas Street   Seattle    WA
#
#      Zip                    Country
# 0  98101   United States of America
# 1  98104   United States of America
# 2  98112   United States of America
# 3  98109   United States of America
# 4  98109   United States of America

# %%
# Convert pandas dataframe to polars
properties_df_pl = pl.from_pandas(properties_df)

# %%
# View top of dataframe to confirm process was successful
properties_df_pl.head(5)
# Out:
# shape: (5, 7)
# ┌─────────────────┬─────────────────┬─────────────────┬──────────┬───────┬───────┬─────────────────┐
# │ Place_ID        ┆ Property        ┆ Address         ┆ City     ┆ State ┆ Zip   ┆ Country         │
# │ ---             ┆ ---             ┆ ---             ┆ ---      ┆ ---   ┆ ---   ┆ ---             │
# │ str             ┆ str             ┆ str             ┆ str      ┆ str   ┆ str   ┆ str             │
# ╞═════════════════╪═════════════════╪═════════════════╪══════════╪═══════╪═══════╪═════════════════╡
# │ 51968bbfbaf5955 ┆ Seattle         ┆ 1483 Alaskan    ┆  Seattle ┆ WA    ┆ 98101 ┆ United States   │
# │ ec059789e04d9c4 ┆ Aquarium        ┆ Way             ┆          ┆       ┆       ┆ of America      │
# │ cd…             ┆                 ┆                 ┆          ┆       ┆       ┆                 │
# │ 51af680970be945 ┆ Frye Art Museum ┆ 704 Terry       ┆  Seattle ┆ WA    ┆ 98104 ┆ United States   │
# │ ec059ab288eb3b8 ┆                 ┆ Avenue          ┆          ┆       ┆       ┆ of America      │
# │ cd…             ┆                 ┆                 ┆          ┆       ┆       ┆                 │
# │ 51cfccbfe11b945 ┆ Seattle Asian   ┆ 1400 East       ┆  Seattle ┆ WA    ┆ 98112 ┆ United States   │
# │ ec059fef6e697ad ┆ Art Museum      ┆ Prospect Street ┆          ┆       ┆       ┆ of America      │
# │ d0…             ┆                 ┆                 ┆          ┆       ┆       ┆                 │
# │ 51a34420657f955 ┆ Center for      ┆ 1010 Valley     ┆  Seattle ┆ WA    ┆ 98109 ┆ United States   │
# │ ec059010bfcf647 ┆ Wooden Boats    ┆ Street          ┆          ┆       ┆       ┆ of America      │
# │ d0…             ┆                 ┆                 ┆          ┆       ┆       ┆                 │
# │ 5140bb4fb48a965 ┆ Seattle         ┆ 201 Thomas      ┆  Seattle ┆ WA    ┆ 98109 ┆ United States   │
# │ ec059ad5a54b66c ┆ Children's      ┆ Street          ┆          ┆       ┆       ┆ of America      │
# │ cf…             ┆ Theater         ┆                 ┆          ┆       ┆       ┆                 │
# └─────────────────┴─────────────────┴─────────────────┴──────────┴───────┴───────┴─────────────────┘

# %%
# Create empty dataframe to hold data for the second table we would like to make that will house category data from the API search
category_table_df = pd.DataFrame(columns = ['Place_ID', 'Category'])

# %%
# Insert each row from the stored json response into categories dataframe
num_of_records = len(json_info['features'])

for i in range(num_of_records):
    place_id_var = json_info["features"][i]["properties"]["place_id"]

    for category in json_info["features"][i]["properties"]["categories"]:
        #print(j)
        new_row = {'Place_ID': place_id_var, 'Category': category}

        #https://stackoverflow.com/questions/75956209/error-dataframe-object-has-no-attribute-append
        category_table_df = category_table_df._append(new_row, ignore_index = True)

# %%
# Convert to polars dataframe, display head of dataframe so that we can see if the process was successful
category_table_df_pl = pl.from_pandas(category_table_df)
category_table_df_pl.head(5)
# Out:
# shape: (5, 2)
# ┌───────────────────────────────────┬────────────────────────┐
# │ Place_ID                          ┆ Category               │
# │ ---                               ┆ ---                    │
# │ str                               ┆ str                    │
# ╞═══════════════════════════════════╪════════════════════════╡
# │ 51968bbfbaf5955ec059789e04d9c4cd… ┆ building               │
# │ 51968bbfbaf5955ec059789e04d9c4cd… ┆ building.tourism       │
# │ 51968bbfbaf5955ec059789e04d9c4cd… ┆ entertainment          │
# │ 51968bbfbaf5955ec059789e04d9c4cd… ┆ entertainment.aquarium │
# │ 51968bbfbaf5955ec059789e04d9c4cd… ┆ fee                    │
# └───────────────────────────────────┴────────────────────────┘

# %%
#Next steps...

#Polars doesen't support direct writing to a database. You can proceed in two ways:

#1. Export the DataFrame in an intermediate format (such as .csv using .write_csv()), then import it into the database.
#2. Process it in memory: you can convert the DataFrame in a simpler data structure using .to_dicts(). The result will be a list of dictionaries, 
#   each of them containing a row in key/value format. At this point is easy to insert them into a database using SqlAlchemy or any specific library for your database of choice.

# Doing it the #2 way is what I think they want, but I could be wrong. #1 is probably easier. Either way is fine, I believe.

#Documentation...
#https://docs.pola.rs/py-polars/html/reference/api/polars.DataFrame.write_database.html
#https://www.youtube.com/watch?v=193TtAL-4lc
#https://www.youtube.com/watch?v=CByx7XjYMhw -- This one is just a general polars lesson



data_to_insert = category_table_df_pl.to_dicts()
address_data = properties_df_pl.to_dicts()
#Syntax for writing to database using the #2 method
#category_table_df_pl.write_database(table_name: str, connection: str, *, if_table_exists: DbWriteMode = 'fail', engine: DbWriteEngine = 'sqlalchemy',)
table_name = ""
connection_string = 'postgresql://user:pass@server:port/database'

#This is a guess
# category_table_df_pl.write_database(table_name, connection_string)
#This is return the number of rows affected.
#Don't worry about duplicates. A SQL script can be run to do that.

data_to_insert
# Out:
# [{'Place_ID': '51968bbfbaf5955ec059789e04d9c4cd4740f00101f9010decf4000000000092031053656174746c6520417175617269756d',
#   'Category': 'building'},
#  {'Place_ID': '51968bbfbaf5955ec059789e04d9c4cd4740f00101f9010decf4000000000092031053656174746c6520417175617269756d',
#   'Category': 'building.tourism'},
#  {'Place_ID': '51968bbfbaf5955ec059789e04d9c4cd4740f00101f9010decf4000000000092031053656174746c6520417175617269756d',
#   'Category': 'entertainment'},
#  {'Place_ID': '51968bbfbaf5955ec059789e04d9c4cd4740f00101f9010decf4000000000092031053656174746c6520417175617269756d',
#   'Category': 'entertainment.aquarium'},
#  {'Place_ID': '51968bbfbaf5955ec059789e04d9c4cd4740f00101f9010decf4000000000092031053656174746c6520417175617269756d',
#   'Category': 'fee'},
#  {'Place_ID': '51968bbfbaf5955ec059789e04d9c4cd4740f00101f9010decf4000000000092031053656174746c6520417175617269756d',
#   'Category': 'wheelchair'},
#  {'Place_ID': '51968bbfbaf5955ec059789e04d9c4cd4740f00101f9010decf4000000000092031053656174746c6520417175617269756d',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51af680970be945ec059ab288eb3b8cd4740f00101f901a19b30000000000092030f4672796520417274204d757365756d',
#   'Category': 'building'},
#  {'Place_ID': '51af680970be945ec059ab288eb3b8cd4740f00101f901a19b30000000000092030f4672796520417274204d757365756d',
#   'Category': 'building.tourism'},
#  {'Place_ID': '51af680970be945ec059ab288eb3b8cd4740f00101f901a19b30000000000092030f4672796520417274204d757365756d',
#   'Category': 'entertainment'},
#  {'Place_ID': '51af680970be945ec059ab288eb3b8cd4740f00101f901a19b30000000000092030f4672796520417274204d757365756d',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '51af680970be945ec059ab288eb3b8cd4740f00101f901a19b30000000000092030f4672796520417274204d757365756d',
#   'Category': 'no_fee'},
#  {'Place_ID': '51af680970be945ec059ab288eb3b8cd4740f00101f901a19b30000000000092030f4672796520417274204d757365756d',
#   'Category': 'no_fee.no'},
#  {'Place_ID': '51cfccbfe11b945ec059fef6e697add04740f00102f901692132020000000092031853656174746c6520417369616e20417274204d757365756d',
#   'Category': 'building'},
#  {'Place_ID': '51cfccbfe11b945ec059fef6e697add04740f00102f901692132020000000092031853656174746c6520417369616e20417274204d757365756d',
#   'Category': 'building.tourism'},
#  {'Place_ID': '51cfccbfe11b945ec059fef6e697add04740f00102f901692132020000000092031853656174746c6520417369616e20417274204d757365756d',
#   'Category': 'entertainment'},
#  {'Place_ID': '51cfccbfe11b945ec059fef6e697add04740f00102f901692132020000000092031853656174746c6520417369616e20417274204d757365756d',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '51cfccbfe11b945ec059fef6e697add04740f00102f901692132020000000092031853656174746c6520417369616e20417274204d757365756d',
#   'Category': 'fee'},
#  {'Place_ID': '51cfccbfe11b945ec059fef6e697add04740f00102f901692132020000000092031853656174746c6520417369616e20417274204d757365756d',
#   'Category': 'wheelchair'},
#  {'Place_ID': '51cfccbfe11b945ec059fef6e697add04740f00102f901692132020000000092031853656174746c6520417369616e20417274204d757365756d',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51a34420657f955ec059010bfcf647d04740f00102f901a115f7020000000092031743656e74657220666f7220576f6f64656e20426f617473',
#   'Category': 'building'},
#  {'Place_ID': '51a34420657f955ec059010bfcf647d04740f00102f901a115f7020000000092031743656e74657220666f7220576f6f64656e20426f617473',
#   'Category': 'building.tourism'},
#  {'Place_ID': '51a34420657f955ec059010bfcf647d04740f00102f901a115f7020000000092031743656e74657220666f7220576f6f64656e20426f617473',
#   'Category': 'entertainment'},
#  {'Place_ID': '51a34420657f955ec059010bfcf647d04740f00102f901a115f7020000000092031743656e74657220666f7220576f6f64656e20426f617473',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '51a34420657f955ec059010bfcf647d04740f00102f901a115f7020000000092031743656e74657220666f7220576f6f64656e20426f617473',
#   'Category': 'no_fee'},
#  {'Place_ID': '51a34420657f955ec059010bfcf647d04740f00102f901a115f7020000000092031743656e74657220666f7220576f6f64656e20426f617473',
#   'Category': 'no_fee.no'},
#  {'Place_ID': '51a34420657f955ec059010bfcf647d04740f00102f901a115f7020000000092031743656e74657220666f7220576f6f64656e20426f617473',
#   'Category': 'wheelchair'},
#  {'Place_ID': '51a34420657f955ec059010bfcf647d04740f00102f901a115f7020000000092031743656e74657220666f7220576f6f64656e20426f617473',
#   'Category': 'wheelchair.limited'},
#  {'Place_ID': '5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901fdf862030000000092031a53656174746c65204368696c6472656e27732054686561746572',
#   'Category': 'building'},
#  {'Place_ID': '5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901fdf862030000000092031a53656174746c65204368696c6472656e27732054686561746572',
#   'Category': 'building.entertainment'},
#  {'Place_ID': '5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901fdf862030000000092031a53656174746c65204368696c6472656e27732054686561746572',
#   'Category': 'entertainment'},
#  {'Place_ID': '5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901fdf862030000000092031a53656174746c65204368696c6472656e27732054686561746572',
#   'Category': 'entertainment.culture'},
#  {'Place_ID': '5140bb4fb48a965ec059ad5a54b66ccf4740f00102f901fdf862030000000092031a53656174746c65204368696c6472656e27732054686561746572',
#   'Category': 'entertainment.culture.theatre'},
#  {'Place_ID': '5135d4ddc669965ec0593ff1f9366ecf4740f00102f90111a2a1090000000092031843686968756c792047617264656e20616e6420476c617373',
#   'Category': 'entertainment'},
#  {'Place_ID': '5135d4ddc669965ec0593ff1f9366ecf4740f00102f90111a2a1090000000092031843686968756c792047617264656e20616e6420476c617373',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '5135d4ddc669965ec0593ff1f9366ecf4740f00102f90111a2a1090000000092031843686968756c792047617264656e20616e6420476c617373',
#   'Category': 'fee'},
#  {'Place_ID': '51ace2596149965ec0599d04b2c88ccf4740f00102f9011ea2a1090000000092031c4d6f504f503a204d757365756d206f6620506f702043756c74757265',
#   'Category': 'building'},
#  {'Place_ID': '51ace2596149965ec0599d04b2c88ccf4740f00102f9011ea2a1090000000092031c4d6f504f503a204d757365756d206f6620506f702043756c74757265',
#   'Category': 'building.tourism'},
#  {'Place_ID': '51ace2596149965ec0599d04b2c88ccf4740f00102f9011ea2a1090000000092031c4d6f504f503a204d757365756d206f6620506f702043756c74757265',
#   'Category': 'entertainment'},
#  {'Place_ID': '51ace2596149965ec0599d04b2c88ccf4740f00102f9011ea2a1090000000092031c4d6f504f503a204d757365756d206f6620506f702043756c74757265',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '51ace2596149965ec0599d04b2c88ccf4740f00102f9011ea2a1090000000092031c4d6f504f503a204d757365756d206f6620506f702043756c74757265',
#   'Category': 'wheelchair'},
#  {'Place_ID': '51ace2596149965ec0599d04b2c88ccf4740f00102f9011ea2a1090000000092031c4d6f504f503a204d757365756d206f6620506f702043756c74757265',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '513dc087006c955ec059fb202e908fca4740f00102f90155747b0d0000000092031f4c6976696e6720436f6d7075746572733a204d757365756d202b204c616273',
#   'Category': 'building'},
#  {'Place_ID': '513dc087006c955ec059fb202e908fca4740f00102f90155747b0d0000000092031f4c6976696e6720436f6d7075746572733a204d757365756d202b204c616273',
#   'Category': 'building.tourism'},
#  {'Place_ID': '513dc087006c955ec059fb202e908fca4740f00102f90155747b0d0000000092031f4c6976696e6720436f6d7075746572733a204d757365756d202b204c616273',
#   'Category': 'entertainment'},
#  {'Place_ID': '513dc087006c955ec059fb202e908fca4740f00102f90155747b0d0000000092031f4c6976696e6720436f6d7075746572733a204d757365756d202b204c616273',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '513dc087006c955ec059fb202e908fca4740f00102f90155747b0d0000000092031f4c6976696e6720436f6d7075746572733a204d757365756d202b204c616273',
#   'Category': 'wheelchair'},
#  {'Place_ID': '513dc087006c955ec059fb202e908fca4740f00102f90155747b0d0000000092031f4c6976696e6720436f6d7075746572733a204d757365756d202b204c616273',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '512e38c35afd935ec0595db9127ea5cf4740f00102f9015f1cb40d0000000092030953746174696f6e2037',
#   'Category': 'building'},
#  {'Place_ID': '512e38c35afd935ec0595db9127ea5cf4740f00102f9015f1cb40d0000000092030953746174696f6e2037',
#   'Category': 'building.commercial'},
#  {'Place_ID': '512e38c35afd935ec0595db9127ea5cf4740f00102f9015f1cb40d0000000092030953746174696f6e2037',
#   'Category': 'commercial'},
#  {'Place_ID': '512e38c35afd935ec0595db9127ea5cf4740f00102f9015f1cb40d0000000092030953746174696f6e2037',
#   'Category': 'commercial.furniture_and_interior'},
#  {'Place_ID': '51a0638f917b965ec059ff285e4749cf4740f00102f9017f8c8a17000000009203165061636966696320536369656e63652043656e746572',
#   'Category': 'building'},
#  {'Place_ID': '51a0638f917b965ec059ff285e4749cf4740f00102f9017f8c8a17000000009203165061636966696320536369656e63652043656e746572',
#   'Category': 'building.tourism'},
#  {'Place_ID': '51a0638f917b965ec059ff285e4749cf4740f00102f9017f8c8a17000000009203165061636966696320536369656e63652043656e746572',
#   'Category': 'entertainment'},
#  {'Place_ID': '51a0638f917b965ec059ff285e4749cf4740f00102f9017f8c8a17000000009203165061636966696320536369656e63652043656e746572',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '51a0638f917b965ec059ff285e4749cf4740f00102f9017f8c8a17000000009203165061636966696320536369656e63652043656e746572',
#   'Category': 'wheelchair'},
#  {'Place_ID': '51a0638f917b965ec059ff285e4749cf4740f00102f9017f8c8a17000000009203165061636966696320536369656e63652043656e746572',
#   'Category': 'wheelchair.limited'},
#  {'Place_ID': '51263cee9c8b955ec059b8d954be67d04740f00102f901bc79081a000000009203114e6f7274687765737420536561706f7274',
#   'Category': 'entertainment'},
#  {'Place_ID': '51263cee9c8b955ec059b8d954be67d04740f00102f901bc79081a000000009203114e6f7274687765737420536561706f7274',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '5159d43f669d955ec059b7e3efdb99cb4740f00102f9017a099c280000000092031c436f617374204775617264204d757365756d204e6f72746877657374',
#   'Category': 'building'},
#  {'Place_ID': '5159d43f669d955ec059b7e3efdb99cb4740f00102f9017a099c280000000092031c436f617374204775617264204d757365756d204e6f72746877657374',
#   'Category': 'building.tourism'},
#  {'Place_ID': '5159d43f669d955ec059b7e3efdb99cb4740f00102f9017a099c280000000092031c436f617374204775617264204d757365756d204e6f72746877657374',
#   'Category': 'entertainment'},
#  {'Place_ID': '5159d43f669d955ec059b7e3efdb99cb4740f00102f9017a099c280000000092031c436f617374204775617264204d757365756d204e6f72746877657374',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '512312859675945ec059c7cb9b5dadce4740f00103f901647a7d5200000000920318456c6c696f74742042617920426f6f6b20436f6d70616e79',
#   'Category': 'commercial'},
#  {'Place_ID': '512312859675945ec059c7cb9b5dadce4740f00103f901647a7d5200000000920318456c6c696f74742042617920426f6f6b20436f6d70616e79',
#   'Category': 'commercial.books'},
#  {'Place_ID': '512312859675945ec059c7cb9b5dadce4740f00103f901647a7d5200000000920318456c6c696f74742042617920426f6f6b20436f6d70616e79',
#   'Category': 'wheelchair'},
#  {'Place_ID': '512312859675945ec059c7cb9b5dadce4740f00103f901647a7d5200000000920318456c6c696f74742042617920426f6f6b20436f6d70616e79',
#   'Category': 'wheelchair.limited'},
#  {'Place_ID': '513dca77dfe7955ec05950706cc60ece4740f00103f901a7c34c81000000009203094c652050616e696572',
#   'Category': 'commercial'},
#  {'Place_ID': '513dca77dfe7955ec05950706cc60ece4740f00103f901a7c34c81000000009203094c652050616e696572',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '513dca77dfe7955ec05950706cc60ece4740f00103f901a7c34c81000000009203094c652050616e696572',
#   'Category': 'commercial.food_and_drink.bakery'},
#  {'Place_ID': '511726f84b30965ec0591ace34fbf2ce4740f00103f901d226bd8a0000000092030d4c6120506172697369656e6e65',
#   'Category': 'catering'},
#  {'Place_ID': '511726f84b30965ec0591ace34fbf2ce4740f00103f901d226bd8a0000000092030d4c6120506172697369656e6e65',
#   'Category': 'catering.cafe'},
#  {'Place_ID': '511726f84b30965ec0591ace34fbf2ce4740f00103f901d226bd8a0000000092030d4c6120506172697369656e6e65',
#   'Category': 'commercial'},
#  {'Place_ID': '511726f84b30965ec0591ace34fbf2ce4740f00103f901d226bd8a0000000092030d4c6120506172697369656e6e65',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '511726f84b30965ec0591ace34fbf2ce4740f00103f901d226bd8a0000000092030d4c6120506172697369656e6e65',
#   'Category': 'commercial.food_and_drink.bakery'},
#  {'Place_ID': '51f8fbc56cc9955ec05949312fb5efcd4740f00103f90125e7e68e000000009203194c6566742042616e6b20426f6f6b20436f6c6c656374697665',
#   'Category': 'commercial'},
#  {'Place_ID': '51f8fbc56cc9955ec05949312fb5efcd4740f00103f90125e7e68e000000009203194c6566742042616e6b20426f6f6b20436f6c6c656374697665',
#   'Category': 'commercial.books'},
#  {'Place_ID': '51378b170bc3955ec059d48d7b325acd4740f00103f90175832794000000009203165965204f6c646520437572696f736974792053686f70',
#   'Category': 'commercial'},
#  {'Place_ID': '51378b170bc3955ec059d48d7b325acd4740f00103f90175832794000000009203165965204f6c646520437572696f736974792053686f70',
#   'Category': 'commercial.gift_and_souvenir'},
#  {'Place_ID': '513491e39876965ec059d6e81a118ccf4740f00103f90107d3af940000000092031953656174746c65204368696c6472656e2773204d757365756d',
#   'Category': 'entertainment'},
#  {'Place_ID': '513491e39876965ec059d6e81a118ccf4740f00103f90107d3af940000000092031953656174746c65204368696c6472656e2773204d757365756d',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '513491e39876965ec059d6e81a118ccf4740f00103f90107d3af940000000092031953656174746c65204368696c6472656e2773204d757365756d',
#   'Category': 'fee'},
#  {'Place_ID': '513491e39876965ec059d6e81a118ccf4740f00103f90107d3af940000000092031953656174746c65204368696c6472656e2773204d757365756d',
#   'Category': 'wheelchair'},
#  {'Place_ID': '513491e39876965ec059d6e81a118ccf4740f00103f90107d3af940000000092031953656174746c65204368696c6472656e2773204d757365756d',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51f69507e9a9945ec0591c4c055493cc4740f00103f9015806c0b00000000092031657696e67204c756b6520417369616e204d757365756d',
#   'Category': 'entertainment'},
#  {'Place_ID': '51f69507e9a9945ec0591c4c055493cc4740f00103f9015806c0b00000000092031657696e67204c756b6520417369616e204d757365756d',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '51f8b1eec4d1955ec05989839593f5cd4740f00103f901277c2802010000009203104a61636b277320466973682053706f74',
#   'Category': 'commercial'},
#  {'Place_ID': '51f8b1eec4d1955ec05989839593f5cd4740f00103f901277c2802010000009203104a61636b277320466973682053706f74',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '51f8b1eec4d1955ec05989839593f5cd4740f00103f901277c2802010000009203104a61636b277320466973682053706f74',
#   'Category': 'commercial.food_and_drink.seafood'},
#  {'Place_ID': '51247a63528d955ec0599d7c264b52d04740f00103f901684810030100000092031e4d757365756d206f6620486973746f727920616e6420496e647573747279',
#   'Category': 'entertainment'},
#  {'Place_ID': '51247a63528d955ec0599d7c264b52d04740f00103f901684810030100000092031e4d757365756d206f6620486973746f727920616e6420496e647573747279',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '51247a63528d955ec0599d7c264b52d04740f00103f901684810030100000092031e4d757365756d206f6620486973746f727920616e6420496e647573747279',
#   'Category': 'fee'},
#  {'Place_ID': '51247a63528d955ec0599d7c264b52d04740f00103f901684810030100000092031e4d757365756d206f6620486973746f727920616e6420496e647573747279',
#   'Category': 'internet_access'},
#  {'Place_ID': '519d4578dd19955ec05976272ae967cf4740f00102f9015247570300000000920303524549',
#   'Category': 'building'},
#  {'Place_ID': '519d4578dd19955ec05976272ae967cf4740f00102f9015247570300000000920303524549',
#   'Category': 'building.commercial'},
#  {'Place_ID': '519d4578dd19955ec05976272ae967cf4740f00102f9015247570300000000920303524549',
#   'Category': 'commercial'},
#  {'Place_ID': '519d4578dd19955ec05976272ae967cf4740f00102f9015247570300000000920303524549',
#   'Category': 'commercial.outdoor_and_sport'},
#  {'Place_ID': '519d4578dd19955ec05976272ae967cf4740f00102f9015247570300000000920303524549',
#   'Category': 'internet_access'},
#  {'Place_ID': '519d4578dd19955ec05976272ae967cf4740f00102f9015247570300000000920303524549',
#   'Category': 'wheelchair'},
#  {'Place_ID': '519d4578dd19955ec05976272ae967cf4740f00102f9015247570300000000920303524549',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '513554895de8935ec059f75ee106c8ce4740f00101f90182c27b000000000092030d43656e7472616c20436f2d6f70',
#   'Category': 'building'},
#  {'Place_ID': '513554895de8935ec059f75ee106c8ce4740f00101f90182c27b000000000092030d43656e7472616c20436f2d6f70',
#   'Category': 'building.commercial'},
#  {'Place_ID': '513554895de8935ec059f75ee106c8ce4740f00101f90182c27b000000000092030d43656e7472616c20436f2d6f70',
#   'Category': 'commercial'},
#  {'Place_ID': '513554895de8935ec059f75ee106c8ce4740f00101f90182c27b000000000092030d43656e7472616c20436f2d6f70',
#   'Category': 'commercial.supermarket'},
#  {'Place_ID': '513554895de8935ec059f75ee106c8ce4740f00101f90182c27b000000000092030d43656e7472616c20436f2d6f70',
#   'Category': 'wheelchair'},
#  {'Place_ID': '513554895de8935ec059f75ee106c8ce4740f00101f90182c27b000000000092030d43656e7472616c20436f2d6f70',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51c48b40de85955ec0595969d10060ce4740f00102f9012660a102000000009203094e6f72647374726f6d',
#   'Category': 'building'},
#  {'Place_ID': '51c48b40de85955ec0595969d10060ce4740f00102f9012660a102000000009203094e6f72647374726f6d',
#   'Category': 'building.commercial'},
#  {'Place_ID': '51c48b40de85955ec0595969d10060ce4740f00102f9012660a102000000009203094e6f72647374726f6d',
#   'Category': 'commercial'},
#  {'Place_ID': '51c48b40de85955ec0595969d10060ce4740f00102f9012660a102000000009203094e6f72647374726f6d',
#   'Category': 'commercial.department_store'},
#  {'Place_ID': '51c48b40de85955ec0595969d10060ce4740f00102f9012660a102000000009203094e6f72647374726f6d',
#   'Category': 'wheelchair'},
#  {'Place_ID': '51c48b40de85955ec0595969d10060ce4740f00102f9012660a102000000009203094e6f72647374726f6d',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '517e2853f290955ec05959d4dd70d6cd4740f00102f9011e0721040000000092030d42656e61726f79612048616c6c',
#   'Category': 'building'},
#  {'Place_ID': '517e2853f290955ec05959d4dd70d6cd4740f00102f9011e0721040000000092030d42656e61726f79612048616c6c',
#   'Category': 'building.entertainment'},
#  {'Place_ID': '517e2853f290955ec05959d4dd70d6cd4740f00102f9011e0721040000000092030d42656e61726f79612048616c6c',
#   'Category': 'entertainment'},
#  {'Place_ID': '517e2853f290955ec05959d4dd70d6cd4740f00102f9011e0721040000000092030d42656e61726f79612048616c6c',
#   'Category': 'entertainment.culture'},
#  {'Place_ID': '517e2853f290955ec05959d4dd70d6cd4740f00102f9011e0721040000000092030d42656e61726f79612048616c6c',
#   'Category': 'entertainment.culture.theatre'},
#  {'Place_ID': '517e2853f290955ec05959d4dd70d6cd4740f00102f9011e0721040000000092030d42656e61726f79612048616c6c',
#   'Category': 'wheelchair'},
#  {'Place_ID': '517e2853f290955ec05959d4dd70d6cd4740f00102f9011e0721040000000092030d42656e61726f79612048616c6c',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51d3ec91ab81955ec0591b76b73708ca4740f00102f901e509e0050000000092030e54686520486f6d65204465706f74',
#   'Category': 'building'},
#  {'Place_ID': '51d3ec91ab81955ec0591b76b73708ca4740f00102f901e509e0050000000092030e54686520486f6d65204465706f74',
#   'Category': 'building.commercial'},
#  {'Place_ID': '51d3ec91ab81955ec0591b76b73708ca4740f00102f901e509e0050000000092030e54686520486f6d65204465706f74',
#   'Category': 'commercial'},
#  {'Place_ID': '51d3ec91ab81955ec0591b76b73708ca4740f00102f901e509e0050000000092030e54686520486f6d65204465706f74',
#   'Category': 'commercial.houseware_and_hardware'},
#  {'Place_ID': '51d3ec91ab81955ec0591b76b73708ca4740f00102f901e509e0050000000092030e54686520486f6d65204465706f74',
#   'Category': 'commercial.houseware_and_hardware.doityourself'},
#  {'Place_ID': '51d3ec91ab81955ec0591b76b73708ca4740f00102f901e509e0050000000092030e54686520486f6d65204465706f74',
#   'Category': 'wheelchair'},
#  {'Place_ID': '51d3ec91ab81955ec0591b76b73708ca4740f00102f901e509e0050000000092030e54686520486f6d65204465706f74',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51b6cdaf15f4955ec05960bf9d651cd34740f00102f9013029e5060000000092031b4461766964736f6e2048616e646275696c742042696379636c6573',
#   'Category': 'building'},
#  {'Place_ID': '51b6cdaf15f4955ec05960bf9d651cd34740f00102f9013029e5060000000092031b4461766964736f6e2048616e646275696c742042696379636c6573',
#   'Category': 'building.commercial'},
#  {'Place_ID': '51b6cdaf15f4955ec05960bf9d651cd34740f00102f9013029e5060000000092031b4461766964736f6e2048616e646275696c742042696379636c6573',
#   'Category': 'building.industrial'},
#  {'Place_ID': '51b6cdaf15f4955ec05960bf9d651cd34740f00102f9013029e5060000000092031b4461766964736f6e2048616e646275696c742042696379636c6573',
#   'Category': 'commercial'},
#  {'Place_ID': '51b6cdaf15f4955ec05960bf9d651cd34740f00102f9013029e5060000000092031b4461766964736f6e2048616e646275696c742042696379636c6573',
#   'Category': 'commercial.outdoor_and_sport'},
#  {'Place_ID': '51b6cdaf15f4955ec05960bf9d651cd34740f00102f9013029e5060000000092031b4461766964736f6e2048616e646275696c742042696379636c6573',
#   'Category': 'commercial.outdoor_and_sport.bicycle'},
#  {'Place_ID': '51230fc5c71d955ec05958264966f4cd4740f00102f901948b620800000000920311546f776e2048616c6c2053656174746c65',
#   'Category': 'activity'},
#  {'Place_ID': '51230fc5c71d955ec05958264966f4cd4740f00102f901948b620800000000920311546f776e2048616c6c2053656174746c65',
#   'Category': 'activity.community_center'},
#  {'Place_ID': '51230fc5c71d955ec05958264966f4cd4740f00102f901948b620800000000920311546f776e2048616c6c2053656174746c65',
#   'Category': 'building'},
#  {'Place_ID': '51230fc5c71d955ec05958264966f4cd4740f00102f901948b620800000000920311546f776e2048616c6c2053656174746c65',
#   'Category': 'building.public_and_civil'},
#  {'Place_ID': '51633581cf51935ec0596a1f9a6f69cb4740f00102f90178217409000000009203214e6f72746877657374204166726963616e20416d65726963616e204d757365756d',
#   'Category': 'building'},
#  {'Place_ID': '51633581cf51935ec0596a1f9a6f69cb4740f00102f90178217409000000009203214e6f72746877657374204166726963616e20416d65726963616e204d757365756d',
#   'Category': 'building.tourism'},
#  {'Place_ID': '51633581cf51935ec0596a1f9a6f69cb4740f00102f90178217409000000009203214e6f72746877657374204166726963616e20416d65726963616e204d757365756d',
#   'Category': 'entertainment'},
#  {'Place_ID': '51633581cf51935ec0596a1f9a6f69cb4740f00102f90178217409000000009203214e6f72746877657374204166726963616e20416d65726963616e204d757365756d',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '5116e8b181a1965ec059795d4a78dacf4740f00102f9019bbe99090000000092031953656174746c65205265706572746f72792054686561747265',
#   'Category': 'building'},
#  {'Place_ID': '5116e8b181a1965ec059795d4a78dacf4740f00102f9019bbe99090000000092031953656174746c65205265706572746f72792054686561747265',
#   'Category': 'building.entertainment'},
#  {'Place_ID': '5116e8b181a1965ec059795d4a78dacf4740f00102f9019bbe99090000000092031953656174746c65205265706572746f72792054686561747265',
#   'Category': 'entertainment'},
#  {'Place_ID': '5116e8b181a1965ec059795d4a78dacf4740f00102f9019bbe99090000000092031953656174746c65205265706572746f72792054686561747265',
#   'Category': 'entertainment.culture'},
#  {'Place_ID': '5116e8b181a1965ec059795d4a78dacf4740f00102f9019bbe99090000000092031953656174746c65205265706572746f72792054686561747265',
#   'Category': 'entertainment.culture.theatre'},
#  {'Place_ID': '5116e8b181a1965ec059795d4a78dacf4740f00102f9019bbe99090000000092031953656174746c65205265706572746f72792054686561747265',
#   'Category': 'wheelchair'},
#  {'Place_ID': '5116e8b181a1965ec059795d4a78dacf4740f00102f9019bbe99090000000092031953656174746c65205265706572746f72792054686561747265',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51eb987bd054975ec05953982feae4d14740f00102f901036b0a0b0000000092030c4b656e2773204d61726b6574',
#   'Category': 'building'},
#  {'Place_ID': '51eb987bd054975ec05953982feae4d14740f00102f901036b0a0b0000000092030c4b656e2773204d61726b6574',
#   'Category': 'building.commercial'},
#  {'Place_ID': '51eb987bd054975ec05953982feae4d14740f00102f901036b0a0b0000000092030c4b656e2773204d61726b6574',
#   'Category': 'commercial'},
#  {'Place_ID': '51eb987bd054975ec05953982feae4d14740f00102f901036b0a0b0000000092030c4b656e2773204d61726b6574',
#   'Category': 'commercial.supermarket'},
#  {'Place_ID': '51eb987bd054975ec05953982feae4d14740f00102f901036b0a0b0000000092030c4b656e2773204d61726b6574',
#   'Category': 'wheelchair'},
#  {'Place_ID': '51eb987bd054975ec05953982feae4d14740f00102f901036b0a0b0000000092030c4b656e2773204d61726b6574',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '5156eea436df965ec059a84e392d47d14740f00102f901c7ac4a0b0000000092030f4d6f6f6e726973652042616b657279',
#   'Category': 'building'},
#  {'Place_ID': '5156eea436df965ec059a84e392d47d14740f00102f901c7ac4a0b0000000092030f4d6f6f6e726973652042616b657279',
#   'Category': 'building.catering'},
#  {'Place_ID': '5156eea436df965ec059a84e392d47d14740f00102f901c7ac4a0b0000000092030f4d6f6f6e726973652042616b657279',
#   'Category': 'building.commercial'},
#  {'Place_ID': '5156eea436df965ec059a84e392d47d14740f00102f901c7ac4a0b0000000092030f4d6f6f6e726973652042616b657279',
#   'Category': 'commercial'},
#  {'Place_ID': '5156eea436df965ec059a84e392d47d14740f00102f901c7ac4a0b0000000092030f4d6f6f6e726973652042616b657279',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '5156eea436df965ec059a84e392d47d14740f00102f901c7ac4a0b0000000092030f4d6f6f6e726973652042616b657279',
#   'Category': 'commercial.food_and_drink.bakery'},
#  {'Place_ID': '512387f7f71d975ec05981673e8dd8d14740f00102f9014136b20b0000000092031d4669766520436f726e65727320486172647761726520436f6d70616e79',
#   'Category': 'building'},
#  {'Place_ID': '512387f7f71d975ec05981673e8dd8d14740f00102f9014136b20b0000000092031d4669766520436f726e65727320486172647761726520436f6d70616e79',
#   'Category': 'building.commercial'},
#  {'Place_ID': '512387f7f71d975ec05981673e8dd8d14740f00102f9014136b20b0000000092031d4669766520436f726e65727320486172647761726520436f6d70616e79',
#   'Category': 'commercial'},
#  {'Place_ID': '512387f7f71d975ec05981673e8dd8d14740f00102f9014136b20b0000000092031d4669766520436f726e65727320486172647761726520436f6d70616e79',
#   'Category': 'commercial.houseware_and_hardware'},
#  {'Place_ID': '512387f7f71d975ec05981673e8dd8d14740f00102f9014136b20b0000000092031d4669766520436f726e65727320486172647761726520436f6d70616e79',
#   'Category': 'commercial.houseware_and_hardware.hardware_and_tools'},
#  {'Place_ID': '51f509d050d3945ec0590a125214e7c94740f00102f9010a407b0d00000000920313506172616d6f756e74204d6f746f7273204e57',
#   'Category': 'building'},
#  {'Place_ID': '51f509d050d3945ec0590a125214e7c94740f00102f9010a407b0d00000000920313506172616d6f756e74204d6f746f7273204e57',
#   'Category': 'building.commercial'},
#  {'Place_ID': '51f509d050d3945ec0590a125214e7c94740f00102f9010a407b0d00000000920313506172616d6f756e74204d6f746f7273204e57',
#   'Category': 'commercial'},
#  {'Place_ID': '51f509d050d3945ec0590a125214e7c94740f00102f9010a407b0d00000000920313506172616d6f756e74204d6f746f7273204e57',
#   'Category': 'commercial.vehicle'},
#  {'Place_ID': '5181f356815b935ec0598e47360b7bce4740f00102f90192aaa20d00000000920319556e636c6520496b652773202d20426f74746c652053686f70',
#   'Category': 'building'},
#  {'Place_ID': '5181f356815b935ec0598e47360b7bce4740f00102f90192aaa20d00000000920319556e636c6520496b652773202d20426f74746c652053686f70',
#   'Category': 'building.commercial'},
#  {'Place_ID': '5181f356815b935ec0598e47360b7bce4740f00102f90192aaa20d00000000920319556e636c6520496b652773202d20426f74746c652053686f70',
#   'Category': 'commercial'},
#  {'Place_ID': '5181f356815b935ec0598e47360b7bce4740f00102f90192aaa20d00000000920319556e636c6520496b652773202d20426f74746c652053686f70',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '5181f356815b935ec0598e47360b7bce4740f00102f90192aaa20d00000000920319556e636c6520496b652773202d20426f74746c652053686f70',
#   'Category': 'commercial.food_and_drink.drinks'},
#  {'Place_ID': '519ef1069f3f935ec0595f0a5c6e6dce4740f00102f90124ada20d00000000920306506f6e646572',
#   'Category': 'building'},
#  {'Place_ID': '519ef1069f3f935ec0595f0a5c6e6dce4740f00102f90124ada20d00000000920306506f6e646572',
#   'Category': 'building.commercial'},
#  {'Place_ID': '519ef1069f3f935ec0595f0a5c6e6dce4740f00102f90124ada20d00000000920306506f6e646572',
#   'Category': 'commercial'},
#  {'Place_ID': '519ef1069f3f935ec0595f0a5c6e6dce4740f00102f90124ada20d00000000920306506f6e646572',
#   'Category': 'commercial.smoking'},
#  {'Place_ID': '51883eb160fc935ec05998c630f0d2cf4740f00102f901672db30d0000000092030957616c677265656e73',
#   'Category': 'building'},
#  {'Place_ID': '51883eb160fc935ec05998c630f0d2cf4740f00102f901672db30d0000000092030957616c677265656e73',
#   'Category': 'building.commercial'},
#  {'Place_ID': '51883eb160fc935ec05998c630f0d2cf4740f00102f901672db30d0000000092030957616c677265656e73',
#   'Category': 'commercial'},
#  {'Place_ID': '51883eb160fc935ec05998c630f0d2cf4740f00102f901672db30d0000000092030957616c677265656e73',
#   'Category': 'commercial.chemist'},
#  {'Place_ID': '51201d9929c1975ec05953068f6ff7c84740f00102f901cfd5c80d00000000920310416c6b69204175746f20526570616972',
#   'Category': 'building'},
#  {'Place_ID': '51201d9929c1975ec05953068f6ff7c84740f00102f901cfd5c80d00000000920310416c6b69204175746f20526570616972',
#   'Category': 'building.commercial'},
#  {'Place_ID': '51201d9929c1975ec05953068f6ff7c84740f00102f901cfd5c80d00000000920310416c6b69204175746f20526570616972',
#   'Category': 'commercial'},
#  {'Place_ID': '51201d9929c1975ec05953068f6ff7c84740f00102f901cfd5c80d00000000920310416c6b69204175746f20526570616972',
#   'Category': 'service'},
#  {'Place_ID': '51201d9929c1975ec05953068f6ff7c84740f00102f901cfd5c80d00000000920310416c6b69204175746f20526570616972',
#   'Category': 'service.vehicle'},
#  {'Place_ID': '51201d9929c1975ec05953068f6ff7c84740f00102f901cfd5c80d00000000920310416c6b69204175746f20526570616972',
#   'Category': 'service.vehicle.repair'},
#  {'Place_ID': '51201d9929c1975ec05953068f6ff7c84740f00102f901cfd5c80d00000000920310416c6b69204175746f20526570616972',
#   'Category': 'service.vehicle.repair.car'},
#  {'Place_ID': '5190debb3fc5955ec059e5ef2cd9bfcf4740f00102f90172d5ce0d0000000092030f4174686c6574696320417761726473',
#   'Category': 'building'},
#  {'Place_ID': '5190debb3fc5955ec059e5ef2cd9bfcf4740f00102f90172d5ce0d0000000092030f4174686c6574696320417761726473',
#   'Category': 'building.commercial'},
#  {'Place_ID': '5190debb3fc5955ec059e5ef2cd9bfcf4740f00102f90172d5ce0d0000000092030f4174686c6574696320417761726473',
#   'Category': 'commercial'},
#  {'Place_ID': '5190debb3fc5955ec059e5ef2cd9bfcf4740f00102f90172d5ce0d0000000092030f4174686c6574696320417761726473',
#   'Category': 'commercial.outdoor_and_sport'},
#  {'Place_ID': '51a41e63f70d965ec059f4a0398c25d34740f00102f901c1d1000e00000000920313557262616e204561727468204e757273657279',
#   'Category': 'building'},
#  {'Place_ID': '51a41e63f70d965ec059f4a0398c25d34740f00102f901c1d1000e00000000920313557262616e204561727468204e757273657279',
#   'Category': 'building.commercial'},
#  {'Place_ID': '51a41e63f70d965ec059f4a0398c25d34740f00102f901c1d1000e00000000920313557262616e204561727468204e757273657279',
#   'Category': 'commercial'},
#  {'Place_ID': '51a41e63f70d965ec059f4a0398c25d34740f00102f901c1d1000e00000000920313557262616e204561727468204e757273657279',
#   'Category': 'commercial.garden'},
#  {'Place_ID': '510c07614d0c965ec059210fc4189dce4740f00102f901011cc1130000000092031644616e27732042656c6c746f776e2047726f63657279',
#   'Category': 'building'},
#  {'Place_ID': '510c07614d0c965ec059210fc4189dce4740f00102f901011cc1130000000092031644616e27732042656c6c746f776e2047726f63657279',
#   'Category': 'building.commercial'},
#  {'Place_ID': '510c07614d0c965ec059210fc4189dce4740f00102f901011cc1130000000092031644616e27732042656c6c746f776e2047726f63657279',
#   'Category': 'commercial'},
#  {'Place_ID': '510c07614d0c965ec059210fc4189dce4740f00102f901011cc1130000000092031644616e27732042656c6c746f776e2047726f63657279',
#   'Category': 'commercial.supermarket'},
#  {'Place_ID': '510c07614d0c965ec059210fc4189dce4740f00102f901011cc1130000000092031644616e27732042656c6c746f776e2047726f63657279',
#   'Category': 'wheelchair'},
#  {'Place_ID': '510c07614d0c965ec059210fc4189dce4740f00102f901011cc1130000000092031644616e27732042656c6c746f776e2047726f63657279',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '5110ae80423d955ec059257d4084b8cc4740f00103f9012f8640150000000092032b4b6c6f6e64696b6520476f6c642052757368204e6174696f6e616c20486973746f726963616c205061726b',
#   'Category': 'entertainment'},
#  {'Place_ID': '5110ae80423d955ec059257d4084b8cc4740f00103f9012f8640150000000092032b4b6c6f6e64696b6520476f6c642052757368204e6174696f6e616c20486973746f726963616c205061726b',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '5110ae80423d955ec059257d4084b8cc4740f00103f9012f8640150000000092032b4b6c6f6e64696b6520476f6c642052757368204e6174696f6e616c20486973746f726963616c205061726b',
#   'Category': 'no_fee'},
#  {'Place_ID': '5110ae80423d955ec059257d4084b8cc4740f00103f9012f8640150000000092032b4b6c6f6e64696b6520476f6c642052757368204e6174696f6e616c20486973746f726963616c205061726b',
#   'Category': 'no_fee.no'},
#  {'Place_ID': '5110ae80423d955ec059257d4084b8cc4740f00103f9012f8640150000000092032b4b6c6f6e64696b6520476f6c642052757368204e6174696f6e616c20486973746f726963616c205061726b',
#   'Category': 'wheelchair'},
#  {'Place_ID': '5110ae80423d955ec059257d4084b8cc4740f00103f9012f8640150000000092032b4b6c6f6e64696b6520476f6c642052757368204e6174696f6e616c20486973746f726963616c205061726b',
#   'Category': 'wheelchair.limited'},
#  {'Place_ID': '51d8c0e85356935ec0598484b82282ce4740f00102f90115c2a61500000000920314556e636c6520496b65277320506f742053686f70',
#   'Category': 'building'},
#  {'Place_ID': '51d8c0e85356935ec0598484b82282ce4740f00102f90115c2a61500000000920314556e636c6520496b65277320506f742053686f70',
#   'Category': 'building.commercial'},
#  {'Place_ID': '51d8c0e85356935ec0598484b82282ce4740f00102f90115c2a61500000000920314556e636c6520496b65277320506f742053686f70',
#   'Category': 'commercial'},
#  {'Place_ID': '51d8c0e85356935ec0598484b82282ce4740f00102f90115c2a61500000000920314556e636c6520496b65277320506f742053686f70',
#   'Category': 'commercial.smoking'},
#  {'Place_ID': '51a2af20cd58935ec0592870c0a3d7d14740f00103f9015706991b000000009203154d6f6e746c616b652042696379636c652053686f70',
#   'Category': 'commercial'},
#  {'Place_ID': '51a2af20cd58935ec0592870c0a3d7d14740f00103f9015706991b000000009203154d6f6e746c616b652042696379636c652053686f70',
#   'Category': 'commercial.outdoor_and_sport'},
#  {'Place_ID': '51a2af20cd58935ec0592870c0a3d7d14740f00103f9015706991b000000009203154d6f6e746c616b652042696379636c652053686f70',
#   'Category': 'commercial.outdoor_and_sport.bicycle'},
#  {'Place_ID': '51a2af20cd58935ec0592870c0a3d7d14740f00103f9015706991b000000009203154d6f6e746c616b652042696379636c652053686f70',
#   'Category': 'rental'},
#  {'Place_ID': '51a2af20cd58935ec0592870c0a3d7d14740f00103f9015706991b000000009203154d6f6e746c616b652042696379636c652053686f70',
#   'Category': 'rental.bicycle'},
#  {'Place_ID': '51581f8075c0945ec05932436b9fffcb4740f00102f901fce6221e0000000092030b424d572053656174746c65',
#   'Category': 'building'},
#  {'Place_ID': '51581f8075c0945ec05932436b9fffcb4740f00102f901fce6221e0000000092030b424d572053656174746c65',
#   'Category': 'building.commercial'},
#  {'Place_ID': '51581f8075c0945ec05932436b9fffcb4740f00102f901fce6221e0000000092030b424d572053656174746c65',
#   'Category': 'commercial'},
#  {'Place_ID': '51581f8075c0945ec05932436b9fffcb4740f00102f901fce6221e0000000092030b424d572053656174746c65',
#   'Category': 'commercial.vehicle'},
#  {'Place_ID': '51897c975297965ec0591add96bdb6cf4740f00103f901dcd6df370000000092030c412f4e542047616c6c657279',
#   'Category': 'entertainment'},
#  {'Place_ID': '51897c975297965ec0591add96bdb6cf4740f00103f901dcd6df370000000092030c412f4e542047616c6c657279',
#   'Category': 'entertainment.culture'},
#  {'Place_ID': '51897c975297965ec0591add96bdb6cf4740f00103f901dcd6df370000000092030c412f4e542047616c6c657279',
#   'Category': 'entertainment.culture.gallery'},
#  {'Place_ID': '514fd367075c955ec0599afdd885d5d24740f00103f901a9330e4d0000000092030a557262616e2053757266',
#   'Category': 'commercial'},
#  {'Place_ID': '514fd367075c955ec0599afdd885d5d24740f00103f901a9330e4d0000000092030a557262616e2053757266',
#   'Category': 'commercial.outdoor_and_sport'},
#  {'Place_ID': '51329413edaa955ec0597ff0ca23c9cd4740f00103f90101555f6e0000000092031253656174746c6520417274204d757365756d',
#   'Category': 'entertainment'},
#  {'Place_ID': '51329413edaa955ec0597ff0ca23c9cd4740f00103f90101555f6e0000000092031253656174746c6520417274204d757365756d',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '51329413edaa955ec0597ff0ca23c9cd4740f00103f90101555f6e0000000092031253656174746c6520417274204d757365756d',
#   'Category': 'fee'},
#  {'Place_ID': '51329413edaa955ec0597ff0ca23c9cd4740f00103f90101555f6e0000000092031253656174746c6520417274204d757365756d',
#   'Category': 'internet_access'},
#  {'Place_ID': '51113235aea4955ec059e8d938fc24cf4740f00103f901394f4e730000000092031257686f6c6520466f6f6473204d61726b6574',
#   'Category': 'commercial'},
#  {'Place_ID': '51113235aea4955ec059e8d938fc24cf4740f00103f901394f4e730000000092031257686f6c6520466f6f6473204d61726b6574',
#   'Category': 'commercial.supermarket'},
#  {'Place_ID': '51113235aea4955ec059e8d938fc24cf4740f00103f901394f4e730000000092031257686f6c6520466f6f6473204d61726b6574',
#   'Category': 'wheelchair'},
#  {'Place_ID': '51113235aea4955ec059e8d938fc24cf4740f00103f901394f4e730000000092031257686f6c6520466f6f6473204d61726b6574',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51f303577902965ec0595d16f41d57ce4740f00103f90180806c740000000092030950617461676f6e6961',
#   'Category': 'commercial'},
#  {'Place_ID': '51f303577902965ec0595d16f41d57ce4740f00103f90180806c740000000092030950617461676f6e6961',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '51f303577902965ec0595d16f41d57ce4740f00103f90180806c740000000092030950617461676f6e6961',
#   'Category': 'commercial.clothing.clothes'},
#  {'Place_ID': '512429e96168975ec059669b954edad14740f00103f901fd0bb474000000009203174d616372696e612042616b657279202d204d6347726177',
#   'Category': 'commercial'},
#  {'Place_ID': '512429e96168975ec059669b954edad14740f00103f901fd0bb474000000009203174d616372696e612042616b657279202d204d6347726177',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '512429e96168975ec059669b954edad14740f00103f901fd0bb474000000009203174d616372696e612042616b657279202d204d6347726177',
#   'Category': 'commercial.food_and_drink.bakery'},
#  {'Place_ID': '512429e96168975ec059669b954edad14740f00103f901fd0bb474000000009203174d616372696e612042616b657279202d204d6347726177',
#   'Category': 'wheelchair'},
#  {'Place_ID': '512429e96168975ec059669b954edad14740f00103f901fd0bb474000000009203174d616372696e612042616b657279202d204d6347726177',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51e40ade46b9965ec0595e95646df8cf4740f00103f901671f1f76000000009203134d6574726f706f6c6974616e204d61726b6574',
#   'Category': 'commercial'},
#  {'Place_ID': '51e40ade46b9965ec0595e95646df8cf4740f00103f901671f1f76000000009203134d6574726f706f6c6974616e204d61726b6574',
#   'Category': 'commercial.supermarket'},
#  {'Place_ID': '51e40ade46b9965ec0595e95646df8cf4740f00103f901671f1f76000000009203134d6574726f706f6c6974616e204d61726b6574',
#   'Category': 'wheelchair'},
#  {'Place_ID': '51e40ade46b9965ec0595e95646df8cf4740f00103f901671f1f76000000009203134d6574726f706f6c6974616e204d61726b6574',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51065850bdda965ec0592b2ea81abdd14740f00103f901a846587800000000920312426c756520486967687761792047616d6573',
#   'Category': 'commercial'},
#  {'Place_ID': '51065850bdda965ec0592b2ea81abdd14740f00103f901a846587800000000920312426c756520486967687761792047616d6573',
#   'Category': 'commercial.hobby'},
#  {'Place_ID': '51065850bdda965ec0592b2ea81abdd14740f00103f901a846587800000000920312426c756520486967687761792047616d6573',
#   'Category': 'commercial.hobby.games'},
#  {'Place_ID': '51065850bdda965ec0592b2ea81abdd14740f00103f901a846587800000000920312426c756520486967687761792047616d6573',
#   'Category': 'commercial.toy_and_game'},
#  {'Place_ID': '519db415a092945ec05943e126987bcf4740f00103f90119a9d07b0000000092030653637265616d',
#   'Category': 'commercial'},
#  {'Place_ID': '519db415a092945ec05943e126987bcf4740f00103f90119a9d07b0000000092030653637265616d',
#   'Category': 'service'},
#  {'Place_ID': '519db415a092945ec05943e126987bcf4740f00103f90119a9d07b0000000092030653637265616d',
#   'Category': 'service.beauty'},
#  {'Place_ID': '519db415a092945ec05943e126987bcf4740f00103f90119a9d07b0000000092030653637265616d',
#   'Category': 'service.beauty.hairdresser'},
#  {'Place_ID': '519db415a092945ec05943e126987bcf4740f00103f90119a9d07b0000000092030653637265616d',
#   'Category': 'wheelchair'},
#  {'Place_ID': '519db415a092945ec05943e126987bcf4740f00103f90119a9d07b0000000092030653637265616d',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '5123ff829323985ec059dfbf89dd88d14740f00103f9011631157c00000000920305506574636f',
#   'Category': 'commercial'},
#  {'Place_ID': '5123ff829323985ec059dfbf89dd88d14740f00103f9011631157c00000000920305506574636f',
#   'Category': 'commercial.pet'},
#  {'Place_ID': '5123ff829323985ec059dfbf89dd88d14740f00103f9011631157c00000000920305506574636f',
#   'Category': 'pet'},
#  {'Place_ID': '5123ff829323985ec059dfbf89dd88d14740f00103f9011631157c00000000920305506574636f',
#   'Category': 'pet.shop'},
#  {'Place_ID': '51082692431f985ec0598d650a9288d14740f00103f9011931157c0000000092031257686f6c6520466f6f6473204d61726b6574',
#   'Category': 'commercial'},
#  {'Place_ID': '51082692431f985ec0598d650a9288d14740f00103f9011931157c0000000092031257686f6c6520466f6f6473204d61726b6574',
#   'Category': 'commercial.supermarket'},
#  {'Place_ID': '5186cb2a6c06945ec059f621a232b4cf4740f00103f901e66a0e7f0000000092031e416461277320546563686e6963616c20426f6f6b7320616e642043616665',
#   'Category': 'catering'},
#  {'Place_ID': '5186cb2a6c06945ec059f621a232b4cf4740f00103f901e66a0e7f0000000092031e416461277320546563686e6963616c20426f6f6b7320616e642043616665',
#   'Category': 'catering.cafe'},
#  {'Place_ID': '5186cb2a6c06945ec059f621a232b4cf4740f00103f901e66a0e7f0000000092031e416461277320546563686e6963616c20426f6f6b7320616e642043616665',
#   'Category': 'commercial'},
#  {'Place_ID': '5186cb2a6c06945ec059f621a232b4cf4740f00103f901e66a0e7f0000000092031e416461277320546563686e6963616c20426f6f6b7320616e642043616665',
#   'Category': 'commercial.books'},
#  {'Place_ID': '5186cb2a6c06945ec059f621a232b4cf4740f00103f901e66a0e7f0000000092031e416461277320546563686e6963616c20426f6f6b7320616e642043616665',
#   'Category': 'internet_access'},
#  {'Place_ID': '514b74965984945ec0597d4d8166c6ce4740f00103f90155a5aa8000000000920305426c69636b',
#   'Category': 'commercial'},
#  {'Place_ID': '51e0fc868906945ec059bef030e24ccf4740f00103f90172eaab800000000092030e42616b657279204e6f7576656175',
#   'Category': 'commercial'},
#  {'Place_ID': '51e0fc868906945ec059bef030e24ccf4740f00103f90172eaab800000000092030e42616b657279204e6f7576656175',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '51e0fc868906945ec059bef030e24ccf4740f00103f90172eaab800000000092030e42616b657279204e6f7576656175',
#   'Category': 'commercial.food_and_drink.bakery'},
#  {'Place_ID': '511c2c9ca4f9945ec059f6b7328cbbce4740f00103f901d132ac80000000009203055261706861',
#   'Category': 'commercial'},
#  {'Place_ID': '511c2c9ca4f9945ec059f6b7328cbbce4740f00103f901d132ac80000000009203055261706861',
#   'Category': 'commercial.outdoor_and_sport'},
#  {'Place_ID': '51226b0da5f6945ec059da426376bbce4740f00103f901d832ac800000000092030a4275636b204d61736f6e',
#   'Category': 'commercial'},
#  {'Place_ID': '51226b0da5f6945ec059da426376bbce4740f00103f901d832ac800000000092030a4275636b204d61736f6e',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '51226b0da5f6945ec059da426376bbce4740f00103f901d832ac800000000092030a4275636b204d61736f6e',
#   'Category': 'commercial.clothing.clothes'},
#  {'Place_ID': '517314200a66945ec0592c225f926fce4740f00103f90129a6b480000000009203074dc3a974696572',
#   'Category': 'commercial'},
#  {'Place_ID': '517314200a66945ec0592c225f926fce4740f00103f90129a6b480000000009203074dc3a974696572',
#   'Category': 'commercial.outdoor_and_sport'},
#  {'Place_ID': '517314200a66945ec0592c225f926fce4740f00103f90129a6b480000000009203074dc3a974696572',
#   'Category': 'commercial.outdoor_and_sport.bicycle'},
#  {'Place_ID': '51f8e8c36977945ec0596547c8da95ce4740f00103f901cba8b4800000000092030442616974',
#   'Category': 'commercial'},
#  {'Place_ID': '51f8e8c36977945ec0596547c8da95ce4740f00103f901cba8b4800000000092030442616974',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '51f8e8c36977945ec0596547c8da95ce4740f00103f901cba8b4800000000092030442616974',
#   'Category': 'commercial.clothing.shoes'},
#  {'Place_ID': '51f8e8c36977945ec0596547c8da95ce4740f00103f901cba8b4800000000092030442616974',
#   'Category': 'wheelchair'},
#  {'Place_ID': '51f8e8c36977945ec0596547c8da95ce4740f00103f901cba8b4800000000092030442616974',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '517e6e0d11dc955ec05988aa594b01ce4740f00103f901f15049810000000092030e43696e6e616d6f6e20576f726b73',
#   'Category': 'commercial'},
#  {'Place_ID': '517e6e0d11dc955ec05988aa594b01ce4740f00103f901f15049810000000092030e43696e6e616d6f6e20576f726b73',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '517e6e0d11dc955ec05988aa594b01ce4740f00103f901f15049810000000092030e43696e6e616d6f6e20576f726b73',
#   'Category': 'commercial.food_and_drink.bakery'},
#  {'Place_ID': '517e6e0d11dc955ec05988aa594b01ce4740f00103f901f15049810000000092030e43696e6e616d6f6e20576f726b73',
#   'Category': 'vegetarian'},
#  {'Place_ID': '514d6a0d4abd955ec05920b2b437f8cd4740f00103f901275149810000000092031453656174746c6520536e65616b65722043697479',
#   'Category': 'commercial'},
#  {'Place_ID': '514d6a0d4abd955ec05920b2b437f8cd4740f00103f901275149810000000092031453656174746c6520536e65616b65722043697479',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '514d6a0d4abd955ec05920b2b437f8cd4740f00103f901275149810000000092031453656174746c6520536e65616b65722043697479',
#   'Category': 'commercial.clothing.shoes'},
#  {'Place_ID': '515f5793a7ac955ec059358c5578e1cd4740f00103f90196c34c8100000000920306546172676574',
#   'Category': 'commercial'},
#  {'Place_ID': '515f5793a7ac955ec059358c5578e1cd4740f00103f90196c34c8100000000920306546172676574',
#   'Category': 'commercial.department_store'},
#  {'Place_ID': '515f5793a7ac955ec059358c5578e1cd4740f00103f90196c34c8100000000920306546172676574',
#   'Category': 'internet_access'},
#  {'Place_ID': '515f5793a7ac955ec059358c5578e1cd4740f00103f90196c34c8100000000920306546172676574',
#   'Category': 'wheelchair'},
#  {'Place_ID': '515f5793a7ac955ec059358c5578e1cd4740f00103f90196c34c8100000000920306546172676574',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51691492ccea955ec0599b2ea6d82cce4740f00103f901a8c34c810000000092030e4d616767696527732053686f6573',
#   'Category': 'commercial'},
#  {'Place_ID': '51691492ccea955ec0599b2ea6d82cce4740f00103f901a8c34c810000000092030e4d616767696527732053686f6573',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '51691492ccea955ec0599b2ea6d82cce4740f00103f901a8c34c810000000092030e4d616767696527732053686f6573',
#   'Category': 'commercial.clothing.shoes'},
#  {'Place_ID': '514cfe277ff7955ec05976456ca521ce4740f00103f901b0c34c810000000092031850696b652026205765737465726e2057696e652053686f70',
#   'Category': 'commercial'},
#  {'Place_ID': '51ff18dfbcdd955ec059ebf218c91ece4740f00103f901d6c34c81000000009203105a65627261636c75622053746f726573',
#   'Category': 'commercial'},
#  {'Place_ID': '51ff18dfbcdd955ec059ebf218c91ece4740f00103f901d6c34c81000000009203105a65627261636c75622053746f726573',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '51ff18dfbcdd955ec059ebf218c91ece4740f00103f901d6c34c81000000009203105a65627261636c75622053746f726573',
#   'Category': 'commercial.clothing.clothes'},
#  {'Place_ID': '51462234828d945ec059c44f4a4794cf4740f00103f901b8858c840000000092030a5370696e204379636c65',
#   'Category': 'commercial'},
#  {'Place_ID': '51462234828d945ec059c44f4a4794cf4740f00103f901b8858c840000000092030a5370696e204379636c65',
#   'Category': 'commercial.video_and_music'},
# ...
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '51e012807f4a955ec059d9be6c7aabcc4740f00103f9018a7e2c8c0000000092031a53616c756d69204172746973616e204375726564204d65617473',
#   'Category': 'commercial.food_and_drink.butcher'},
#  {'Place_ID': '51db98e83d5f955ec059d2a19f8d5ccc4740f00103f901e28f2c8c000000009203124265617374204d6f6465204170706172656c',
#   'Category': 'commercial'},
#  {'Place_ID': '51db98e83d5f955ec059d2a19f8d5ccc4740f00103f901e28f2c8c000000009203124265617374204d6f6465204170706172656c',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '51db98e83d5f955ec059d2a19f8d5ccc4740f00103f901e28f2c8c000000009203124265617374204d6f6465204170706172656c',
#   'Category': 'commercial.clothing.clothes'},
#  {'Place_ID': '51ee7a1ffde5935ec059f1bcaba7fbcb4740f00103f90103936d8d0000000092032053656174746c6520426f756c646572696e672050726f6a656374202d20534250',
#   'Category': 'commercial'},
#  {'Place_ID': '51ee7a1ffde5935ec059f1bcaba7fbcb4740f00103f90103936d8d0000000092032053656174746c6520426f756c646572696e672050726f6a656374202d20534250',
#   'Category': 'commercial.outdoor_and_sport'},
#  {'Place_ID': '51ee7a1ffde5935ec059f1bcaba7fbcb4740f00103f90103936d8d0000000092032053656174746c6520426f756c646572696e672050726f6a656374202d20534250',
#   'Category': 'entertainment'},
#  {'Place_ID': '51ee7a1ffde5935ec059f1bcaba7fbcb4740f00103f90103936d8d0000000092032053656174746c6520426f756c646572696e672050726f6a656374202d20534250',
#   'Category': 'entertainment.activity_park'},
#  {'Place_ID': '51ee7a1ffde5935ec059f1bcaba7fbcb4740f00103f90103936d8d0000000092032053656174746c6520426f756c646572696e672050726f6a656374202d20534250',
#   'Category': 'entertainment.activity_park.climbing'},
#  {'Place_ID': '51ee7a1ffde5935ec059f1bcaba7fbcb4740f00103f90103936d8d0000000092032053656174746c6520426f756c646572696e672050726f6a656374202d20534250',
#   'Category': 'sport'},
#  {'Place_ID': '51ee7a1ffde5935ec059f1bcaba7fbcb4740f00103f90103936d8d0000000092032053656174746c6520426f756c646572696e672050726f6a656374202d20534250',
#   'Category': 'sport.sports_centre'},
#  {'Place_ID': '519d8a54185b935ec05962bc1cffaacc4740f00103f901c9b2818d0000000092031153656174746c6520466973682047757973',
#   'Category': 'commercial'},
#  {'Place_ID': '519d8a54185b935ec05962bc1cffaacc4740f00103f901c9b2818d0000000092031153656174746c6520466973682047757973',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '519d8a54185b935ec05962bc1cffaacc4740f00103f901c9b2818d0000000092031153656174746c6520466973682047757973',
#   'Category': 'commercial.food_and_drink.seafood'},
#  {'Place_ID': '514b439e6eea935ec0598c6c536a40cc4740f00103f9013370828d0000000092031542756464202620436f2e204175746f6d6f74697665',
#   'Category': 'commercial'},
#  {'Place_ID': '514b439e6eea935ec0598c6c536a40cc4740f00103f9013370828d0000000092031542756464202620436f2e204175746f6d6f74697665',
#   'Category': 'service'},
#  {'Place_ID': '514b439e6eea935ec0598c6c536a40cc4740f00103f9013370828d0000000092031542756464202620436f2e204175746f6d6f74697665',
#   'Category': 'service.vehicle'},
#  {'Place_ID': '514b439e6eea935ec0598c6c536a40cc4740f00103f9013370828d0000000092031542756464202620436f2e204175746f6d6f74697665',
#   'Category': 'service.vehicle.repair'},
#  {'Place_ID': '514b439e6eea935ec0598c6c536a40cc4740f00103f9013370828d0000000092031542756464202620436f2e204175746f6d6f74697665',
#   'Category': 'service.vehicle.repair.car'},
#  {'Place_ID': '517e2f8507cd935ec059c51c71f618cc4740f00103f901d271828d0000000092030a5468652042696b657279',
#   'Category': 'commercial'},
#  {'Place_ID': '517e2f8507cd935ec059c51c71f618cc4740f00103f901d271828d0000000092030a5468652042696b657279',
#   'Category': 'commercial.outdoor_and_sport'},
#  {'Place_ID': '517e2f8507cd935ec059c51c71f618cc4740f00103f901d271828d0000000092030a5468652042696b657279',
#   'Category': 'commercial.outdoor_and_sport.bicycle'},
#  {'Place_ID': '51d94ae82e89935ec05967c479d278ce4740f00103f90161a4918d0000000092030b32302f3230204379636c65',
#   'Category': 'commercial'},
#  {'Place_ID': '51d94ae82e89935ec05967c479d278ce4740f00103f90161a4918d0000000092030b32302f3230204379636c65',
#   'Category': 'commercial.outdoor_and_sport'},
#  {'Place_ID': '51d94ae82e89935ec05967c479d278ce4740f00103f90161a4918d0000000092030b32302f3230204379636c65',
#   'Category': 'commercial.outdoor_and_sport.bicycle'},
#  {'Place_ID': '51fe929e3333945ec05972504750a1cd4740f00103f9014c41948d000000009203164d697474656e20537765657473202620436f66666565',
#   'Category': 'commercial'},
#  {'Place_ID': '51fe929e3333945ec05972504750a1cd4740f00103f9014c41948d000000009203164d697474656e20537765657473202620436f66666565',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '51fe929e3333945ec05972504750a1cd4740f00103f9014c41948d000000009203164d697474656e20537765657473202620436f66666565',
#   'Category': 'commercial.food_and_drink.bakery'},
#  {'Place_ID': '519918cbf4cb955ec059cd303eb0e3cd4740f00103f901b459e68e0000000092031447686f737420416c6c657920457370726573736f',
#   'Category': 'commercial'},
#  {'Place_ID': '519918cbf4cb955ec059cd303eb0e3cd4740f00103f901b459e68e0000000092031447686f737420416c6c657920457370726573736f',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '519918cbf4cb955ec059cd303eb0e3cd4740f00103f901b459e68e0000000092031447686f737420416c6c657920457370726573736f',
#   'Category': 'commercial.food_and_drink.coffee_and_tea'},
#  {'Place_ID': '5118838769df955ec059cab95db818ce4740f00103f901425ae68e00000000920316416e7469717565732061742050696b6520506c616365',
#   'Category': 'commercial'},
#  {'Place_ID': '5118838769df955ec059cab95db818ce4740f00103f901425ae68e00000000920316416e7469717565732061742050696b6520506c616365',
#   'Category': 'commercial.antiques'},
#  {'Place_ID': '51122ee411dc955ec05986072e84e6cd4740f00103f9018983e68e00000000920315576f726c64205370696365204d65726368616e7473',
#   'Category': 'commercial'},
#  {'Place_ID': '51122ee411dc955ec05986072e84e6cd4740f00103f9018983e68e00000000920315576f726c64205370696365204d65726368616e7473',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '51122ee411dc955ec05986072e84e6cd4740f00103f9018983e68e00000000920315576f726c64205370696365204d65726368616e7473',
#   'Category': 'commercial.food_and_drink.spices'},
#  {'Place_ID': '516290604fe0955ec0592caec3c606ce4740f00103f90120bbe68e0000000092031842656563686572732048616e646d61646520436865657365',
#   'Category': 'commercial'},
#  {'Place_ID': '516290604fe0955ec0592caec3c606ce4740f00103f90120bbe68e0000000092031842656563686572732048616e646d61646520436865657365',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '516290604fe0955ec0592caec3c606ce4740f00103f90120bbe68e0000000092031842656563686572732048616e646d61646520436865657365',
#   'Category': 'commercial.food_and_drink.cheese_and_dairy'},
#  {'Place_ID': '5124e4839ecd955ec059d2d9085ee3cd4740f00103f9015ed9e68e00000000920311446f6e2026204a6f652773204d65617473',
#   'Category': 'commercial'},
#  {'Place_ID': '5124e4839ecd955ec059d2d9085ee3cd4740f00103f9015ed9e68e00000000920311446f6e2026204a6f652773204d65617473',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '5124e4839ecd955ec059d2d9085ee3cd4740f00103f9015ed9e68e00000000920311446f6e2026204a6f652773204d65617473',
#   'Category': 'commercial.food_and_drink.butcher'},
#  {'Place_ID': '5124e4839ecd955ec059d2d9085ee3cd4740f00103f9015ed9e68e00000000920311446f6e2026204a6f652773204d65617473',
#   'Category': 'wheelchair'},
#  {'Place_ID': '5124e4839ecd955ec059d2d9085ee3cd4740f00103f9015ed9e68e00000000920311446f6e2026204a6f652773204d65617473',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51d4b848ebb9955ec059e9a50dc6e3cd4740f00103f9016bd9e68e0000000092031553686f77626f7820617420746865204d61726b6574',
#   'Category': 'entertainment'},
#  {'Place_ID': '51d4b848ebb9955ec059e9a50dc6e3cd4740f00103f9016bd9e68e0000000092031553686f77626f7820617420746865204d61726b6574',
#   'Category': 'entertainment.culture'},
#  {'Place_ID': '51d4b848ebb9955ec059e9a50dc6e3cd4740f00103f9016bd9e68e0000000092031553686f77626f7820617420746865204d61726b6574',
#   'Category': 'entertainment.culture.theatre'},
#  {'Place_ID': '51b6903644cb955ec0597e8cdb02f8cd4740f00103f90107e7e68e000000009203174d6574736b6572204d617073206f662053656174746c65',
#   'Category': 'commercial'},
#  {'Place_ID': '51b6903644cb955ec0597e8cdb02f8cd4740f00103f90107e7e68e000000009203174d6574736b6572204d617073206f662053656174746c65',
#   'Category': 'commercial.books'},
#  {'Place_ID': '51d73730b9d1955ec0592dd66af3ffcd4740f00103f90115e7e68e0000000092030c536f204d756368205961726e',
#   'Category': 'commercial'},
#  {'Place_ID': '51d73730b9d1955ec0592dd66af3ffcd4740f00103f90115e7e68e0000000092030c536f204d756368205961726e',
#   'Category': 'commercial.hobby'},
#  {'Place_ID': '51d73730b9d1955ec0592dd66af3ffcd4740f00103f90115e7e68e0000000092030c536f204d756368205961726e',
#   'Category': 'commercial.hobby.sewing_and_knitting'},
#  {'Place_ID': '51b4b2d881ce955ec05944b643a7e7cd4740f00103f90121e7e68e0000000092031650696b6520506c6163652046697368204d61726b6574',
#   'Category': 'commercial'},
#  {'Place_ID': '51b4b2d881ce955ec05944b643a7e7cd4740f00103f90121e7e68e0000000092031650696b6520506c6163652046697368204d61726b6574',
#   'Category': 'commercial.food_and_drink'},
#  {'Place_ID': '51b4b2d881ce955ec05944b643a7e7cd4740f00103f90121e7e68e0000000092031650696b6520506c6163652046697368204d61726b6574',
#   'Category': 'commercial.food_and_drink.seafood'},
#  {'Place_ID': '512ce510ccac955ec05927ac4319aacf4740f00103f901dec40c8f00000000920319476f6f6477696c6c20536f757468204c616b6520556e696f6e',
#   'Category': 'commercial'},
#  {'Place_ID': '512ce510ccac955ec05927ac4319aacf4740f00103f901dec40c8f00000000920319476f6f6477696c6c20536f757468204c616b6520556e696f6e',
#   'Category': 'commercial.discount_store'},
#  {'Place_ID': '516cecc84741965ec059df3050583dd04740f00103f901273c1a8f0000000092030c4c756e612053616e64616c73',
#   'Category': 'commercial'},
#  {'Place_ID': '516cecc84741965ec059df3050583dd04740f00103f901273c1a8f0000000092030c4c756e612053616e64616c73',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '516cecc84741965ec059df3050583dd04740f00103f901273c1a8f0000000092030c4c756e612053616e64616c73',
#   'Category': 'commercial.clothing.shoes'},
#  {'Place_ID': '515f9fef5d39965ec059765561cdb7cf4740f00103f90124921b8f0000000092032e42696c6c2026204d656c696e646120476174657320466f756e646174696f6e2056697369746f722043656e746572',
#   'Category': 'entertainment'},
#  {'Place_ID': '515f9fef5d39965ec059765561cdb7cf4740f00103f90124921b8f0000000092032e42696c6c2026204d656c696e646120476174657320466f756e646174696f6e2056697369746f722043656e746572',
#   'Category': 'entertainment.museum'},
#  {'Place_ID': '515f9fef5d39965ec059765561cdb7cf4740f00103f90124921b8f0000000092032e42696c6c2026204d656c696e646120476174657320466f756e646174696f6e2056697369746f722043656e746572',
#   'Category': 'wheelchair'},
#  {'Place_ID': '515f9fef5d39965ec059765561cdb7cf4740f00103f90124921b8f0000000092032e42696c6c2026204d656c696e646120476174657320466f756e646174696f6e2056697369746f722043656e746572',
#   'Category': 'wheelchair.yes'},
#  {'Place_ID': '51f6ebf3bdab965ec0597d60ba4fe9cf4740f00103f90135fe1b8f0000000092030f50616e64612050686f746f204c6162',
#   'Category': 'commercial'},
#  {'Place_ID': '51f6ebf3bdab965ec0597d60ba4fe9cf4740f00103f90135fe1b8f0000000092030f50616e64612050686f746f204c6162',
#   'Category': 'commercial.hobby'},
#  {'Place_ID': '51f6ebf3bdab965ec0597d60ba4fe9cf4740f00103f90135fe1b8f0000000092030f50616e64612050686f746f204c6162',
#   'Category': 'commercial.hobby.photo'},
#  {'Place_ID': '517c3f355e3a955ec059dbee707a72ce4740f00103f90185584d8f00000000920309464153545349474e53',
#   'Category': 'commercial'},
#  {'Place_ID': '51e60de66583955ec05997e1996a1cce4740f00103f90114a84d8f000000009203084361726861727474',
#   'Category': 'commercial'},
#  {'Place_ID': '51e60de66583955ec05997e1996a1cce4740f00103f90114a84d8f000000009203084361726861727474',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '51e60de66583955ec05997e1996a1cce4740f00103f90114a84d8f000000009203084361726861727474',
#   'Category': 'commercial.clothing.clothes'},
#  {'Place_ID': '511070ad9b77955ec0591a00d5c853ce4740f00103f9012ea84d8f0000000092030d45696c65656e20466973686572',
#   'Category': 'commercial'},
#  {'Place_ID': '511070ad9b77955ec0591a00d5c853ce4740f00103f9012ea84d8f0000000092030d45696c65656e20466973686572',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '511070ad9b77955ec0591a00d5c853ce4740f00103f9012ea84d8f0000000092030d45696c65656e20466973686572',
#   'Category': 'commercial.clothing.clothes'},
#  {'Place_ID': '518ac67f2667955ec059ba919ce6d3cd4740f00103f9013add4d8f000000009203094c756c792059616e67',
#   'Category': 'commercial'},
#  {'Place_ID': '518ac67f2667955ec059ba919ce6d3cd4740f00103f9013add4d8f000000009203094c756c792059616e67',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '518ac67f2667955ec059ba919ce6d3cd4740f00103f9013add4d8f000000009203094c756c792059616e67',
#   'Category': 'commercial.clothing.clothes'},
#  {'Place_ID': '51bc37860060955ec05971f28e37f9cd4740f00103f90146dd4d8f00000000920312357468204176656e75652054686561746572',
#   'Category': 'entertainment'},
#  {'Place_ID': '51bc37860060955ec05971f28e37f9cd4740f00103f90146dd4d8f00000000920312357468204176656e75652054686561746572',
#   'Category': 'entertainment.culture'},
#  {'Place_ID': '51bc37860060955ec05971f28e37f9cd4740f00103f90146dd4d8f00000000920312357468204176656e75652054686561746572',
#   'Category': 'entertainment.culture.theatre'},
#  {'Place_ID': '51b7cd9e1562955ec059bdde41e1fdcd4740f00103f90149dd4d8f000000009203084d6570686973746f',
#   'Category': 'commercial'},
#  {'Place_ID': '51b7cd9e1562955ec059bdde41e1fdcd4740f00103f90149dd4d8f000000009203084d6570686973746f',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '51b7cd9e1562955ec059bdde41e1fdcd4740f00103f90149dd4d8f000000009203084d6570686973746f',
#   'Category': 'commercial.clothing.shoes'},
#  {'Place_ID': '51fedf7dfa74955ec05970834694f6cd4740f00103f90151dd4d8f0000000092031550434320436f6d6d756e697479204d61726b657473',
#   'Category': 'commercial'},
#  {'Place_ID': '51fedf7dfa74955ec05970834694f6cd4740f00103f90151dd4d8f0000000092031550434320436f6d6d756e697479204d61726b657473',
#   'Category': 'commercial.supermarket'},
#  {'Place_ID': '5170788bd184955ec059b3fbf42801ce4740f00103f90167dd4d8f0000000092030e4a6f73657068204a6577656c7279',
#   'Category': 'commercial'},
#  {'Place_ID': '5170788bd184955ec059b3fbf42801ce4740f00103f90167dd4d8f0000000092030e4a6f73657068204a6577656c7279',
#   'Category': 'commercial.jewelry'},
#  {'Place_ID': '51c7c1114999955ec059fd9237ff0ace4740f00103f90174dd4d8f00000000920304526f7373',
#   'Category': 'commercial'},
#  {'Place_ID': '51c7c1114999955ec059fd9237ff0ace4740f00103f90174dd4d8f00000000920304526f7373',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '51c7c1114999955ec059fd9237ff0ace4740f00103f90174dd4d8f00000000920304526f7373',
#   'Category': 'commercial.clothing.clothes'},
#  {'Place_ID': '51c7c1114999955ec059fd9237ff0ace4740f00103f90174dd4d8f00000000920304526f7373',
#   'Category': 'commercial.clothing.men'},
#  {'Place_ID': '51c7c1114999955ec059fd9237ff0ace4740f00103f90174dd4d8f00000000920304526f7373',
#   'Category': 'commercial.clothing.women'},
#  {'Place_ID': '51c7c1114999955ec059fd9237ff0ace4740f00103f90174dd4d8f00000000920304526f7373',
#   'Category': 'commercial.department_store'},
#  {'Place_ID': '51becf02feba955ec059ad09c31a1dce4740f00103f901ace74d8f0000000092030b53696d706c65204c696665',
#   'Category': 'commercial'},
#  {'Place_ID': '51becf02feba955ec059ad09c31a1dce4740f00103f901ace74d8f0000000092030b53696d706c65204c696665',
#   'Category': 'commercial.clothing'},
#  {'Place_ID': '51becf02feba955ec059ad09c31a1dce4740f00103f901ace74d8f0000000092030b53696d706c65204c696665',
#   'Category': 'commercial.clothing.clothes'},
#  {'Place_ID': '5163d68ba19c955ec05972c4160be8cd4740f00103f9010aef4d8f0000000092030f54686520547269706c6520446f6f72',
#   'Category': 'entertainment'},
#  {'Place_ID': '5163d68ba19c955ec05972c4160be8cd4740f00103f9010aef4d8f0000000092030f54686520547269706c6520446f6f72',
#   'Category': 'entertainment.culture'},
#  {'Place_ID': '5163d68ba19c955ec05972c4160be8cd4740f00103f9010aef4d8f0000000092030f54686520547269706c6520446f6f72',
#   'Category': 'entertainment.culture.theatre'}]

# %%
# Create CSV file for address data to be imported to PostgreSQL from dataframes, use polars
# pandas way: properties_df.to_csv("address.csv", encoding='utf8', index=False)
properties_df_pl.write_csv("../CSV Files/Addresses.csv", separator=",")

# %%
# Create CSV file for category data to be imported to PostgreSQL from dataframes, use polars
# pandas way: category_table_df.to_csv("category.csv", encoding='utf8', index=False)
category_table_df_pl.write_csv("../CSV Files/Categories.csv", separator=",")
